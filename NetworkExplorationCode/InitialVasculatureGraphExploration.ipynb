# %%
# IMPORTS AND GLOBALS
import os
import shutil
import math
import sys
from typing import *
from enum import Enum
import datetime
import numpy as np
# import pandas as pd
import matplotlib.pyplot as plt
from graph_tool.all import *
import pickle
from functools import reduce
from tqdm import tqdm, tqdm_notebook
import itertools

# %%
path_to_graph_gt = 'BrainVasculatureGraphData/data_graph.gt'
g = load_graph(path_to_graph_gt)
print("Finished reading the graph")

# %%
graph_draw(g,
#            pos=g.properties[('v', 'coordinates')],
#            vertex_size=g.properties[('v', 'radii')],
#            edge_marker_size=g.properties[('e', 'radii')],
#            vertex_fill_color=g.properties[('v', 'artery_raw')],
#            edge_color='artery',
           output=f'graph_full.pdf')

# %%
graph_draw(g,
           pos=g.properties[('v', 'coordinates')],
           vertex_size=g.properties[('v', 'radii')],
           edge_marker_size=g.properties[('e', 'radii')],
#            vertex_fill_color=g.properties[('v', 'artery_raw')],
#            edge_color='artery',
           output=f'graph_full_with_radii_and_pos.pdf')

# %%
graph_draw(g,
           pos=g.properties[('v', 'coordinates')],
           vertex_size=g.properties[('v', 'radii')],
           edge_marker_size=g.properties[('e', 'radii')],
#            vertex_fill_color=g.properties[('v', 'artery_raw')],
#            edge_color='artery',
           output=f'graph_full_with_radii.pdf')

# %%
g.list_properties()
# Out:
# shape                                 (graph)   (type: python::object, val: (43
#                                                                             53,
#                                                                             705
#                                                                             6,
#                                                                             352
#                                                                             3))
# edge_geometry_type                    (graph)   (type: python::object, val: gra
#                                                                             ph)
# edge_geometry_coordinates             (graph)   (type: python::object, val: [[2
#                                                                             180
#                                                                             .
#                                                                             353
#                                                                             2.
#                                                                             28.
#                                                                             ]
#                                                                             [21
#                                                                             79.
#                                                                             353
#                                                                             3.
#                                                                             29.
#                                                                             ]
#                                                                             [21
#                                                                             80.
#                                                                             285
#                                                                             714
#                                                                             29
#                                                                             353
#                                                                             5.2
#                                                                             857
#                                                                             142
#                                                                             9
#                                                                             32.
#                                                                             904
#                                                                             761
#                                                                             9 ]
#                                                                             ...
#                                                                             [29
#                                                                             53.
#                                                                             467
#                                                                             5.
#                                                                             351
#                                                                             7.
#                                                                             ]
#                                                                             [29
#                                                                             53.
#                                                                             467
#                                                                             4.
#                                                                             351
#                                                                             7.
#                                                                             ]
#                                                                             [29
#                                                                             53.
#                                                                             333
#                                                                             333
#                                                                             33
#                                                                             467
#                                                                             2.3
#                                                                             333
#                                                                             333
#                                                                             3 3
#                                                                             517
#                                                                             .
#                                                                             ]])
# edge_geometry_radii                   (graph)   (type: python::object, val: [1.
#                                                                             1.4
#                                                                             142
#                                                                             135
#                                                                             6 2
#                                                                             .82
#                                                                             842
#                                                                             712
#                                                                             ...
#                                                                             1.
#                                                                             1.
#                                                                             1.
#                                                                             ])
# edge_geometry_artery_binary           (graph)   (type: python::object, val: [Fa
#                                                                             lse
#                                                                             Fal
#                                                                             se
#                                                                             Fal
#                                                                             se
#                                                                             ...
#                                                                             Fal
#                                                                             se
#                                                                             Fal
#                                                                             se
#                                                                             Fal
#                                                                             se])
# edge_geometry_artery_raw              (graph)   (type: python::object, val: [41
#                                                                             6.
#                                                                             439
#                                                                             . 4
#                                                                             39.
#                                                                             ...
#                                                                             324
#                                                                             . 3
#                                                                             24.
#                                                                             324
#                                                                             .])
# edge_geometry_coordinates_atlas       (graph)   (type: python::object, val: [[1
#                                                                             48.
#                                                                             401
#                                                                             287
#                                                                             84
#                                                                             321
#                                                                             .41
#                                                                             753
#                                                                             457
#                                                                             21.
#                                                                             146
#                                                                             407
#                                                                             18]
#                                                                             [14
#                                                                             8.3
#                                                                             262
#                                                                             315
#                                                                             5 3
#                                                                             21.
#                                                                             483
#                                                                             845
#                                                                             4
#                                                                             21.
#                                                                             210
#                                                                             095
#                                                                             92]
#                                                                             [14
#                                                                             8.3
#                                                                             977
#                                                                             538
#                                                                             4 3
#                                                                             21.
#                                                                             630
#                                                                             358
#                                                                             94
#                                                                             21.
#                                                                             444
#                                                                             773
#                                                                             21]
#                                                                             ...
#                                                                             [20
#                                                                             1.7
#                                                                             085
#                                                                             573
#                                                                             8 3
#                                                                             83.
#                                                                             585
#                                                                             823
#                                                                             55
#                                                                             249
#                                                                             .00
#                                                                             569
#                                                                             66
#                                                                             ]
#                                                                             [20
#                                                                             1.7
#                                                                             070
#                                                                             231
#                                                                             9 3
#                                                                             83.
#                                                                             517
#                                                                             641
#                                                                             8
#                                                                             249
#                                                                             .00
#                                                                             333
#                                                                             924
#                                                                             ]
#                                                                             [20
#                                                                             1.7
#                                                                             305
#                                                                             573
#                                                                             2 3
#                                                                             83.
#                                                                             403
#                                                                             797
#                                                                             2
#                                                                             248
#                                                                             .99
#                                                                             923
#                                                                             58
#                                                                             ]])
# edge_geometry_radii_atlas             (graph)   (type: python::object, val: [0.
#                                                                             069
#                                                                             941
#                                                                             74
#                                                                             0.0
#                                                                             989
#                                                                             125
#                                                                             6 0
#                                                                             .19
#                                                                             782
#                                                                             512
#                                                                             ...
#                                                                             0.0
#                                                                             699
#                                                                             417
#                                                                             4 0
#                                                                             .06
#                                                                             994
#                                                                             174
#                                                                             0.0
#                                                                             699
#                                                                             417
#                                                                             4])
# edge_geometry_annotation              (graph)   (type: python::object, val: [36
#                                                                             7
#                                                                             367
#                                                                             367
#                                                                             ...
#                                                                             0
#                                                                             0
#                                                                             0])
# edge_geometry_distance_to_surface     (graph)   (type: python::object, val: [
#                                                                             1.
#                                                                             1.
#                                                                             1.
#                                                                             ...
#                                                                             47.
#                                                                             549
#                                                                             973
#                                                                             47.
#                                                                             549
#                                                                             973
#                                                                             47.
#                                                                             169
#                                                                             907
#                                                                             ])
# annotation                            (vertex)  (type: int64_t)
# artery_binary                         (vertex)  (type: bool)
# artery_raw                            (vertex)  (type: double)
# coordinates                           (vertex)  (type: vector<double>)
# coordinates_atlas                     (vertex)  (type: vector<double>)
# distance_to_surface                   (vertex)  (type: double)
# radii                                 (vertex)  (type: double)
# radii_atlas                           (vertex)  (type: double)
# artery                                (edge)    (type: bool)
# artery_binary                         (edge)    (type: bool)
# artery_raw                            (edge)    (type: double)
# distance_to_surface                   (edge)    (type: double)
# edge_geometry_indices                 (edge)    (type: vector<int64_t>)
# length                                (edge)    (type: double)
# radii                                 (edge)    (type: double)
# radii_atlas                           (edge)    (type: double)
# vein                                  (edge)    (type: bool)
# vein_big                              (edge)    (type: bool)

# %%
dir_path = 'properties_exploration/vertices_properties_exploration/'
os.makedirs(dir_path, exist_ok=True)
with open(os.path.join(dir_path, 'vertices_properties_exploration.txt'), 'w') as f:
    for prop in ('annotation', 
                 'artery_binary', 
                 'artery_raw', 
                 'coordinates',
                 'coordinates_atlas',
                 'distance_to_surface', 
                 'radii', 
                 'radii_atlas'):
        print(f"exploring: {prop}")
        f.write(f"{'#'*10}\n{prop} exploration:\n")
        try:
            prop_mean = g.vertex_properties[prop].mean()
            f.write(f"{prop} mean: {prop_mean}\n")
        except: 
            print(f"could not calc mean on prop: {prop}")
        try:
            prop_std = g.vertex_properties[prop].std()
            f.write(f"{prop} std: {prop_std}\n")
        except: 
            print(f"could not calc std on prop: {prop}")
        try:
            prop_min = g.vertex_properties[prop].min()
            f.write(f"{prop} min: {prop_min}\n")
        except: 
            print(f"could not calc min on prop: {prop}")
        try:
            prop_max = g.vertex_properties[prop].max()
            f.write(f"{prop} max: {prop_max}\n")
        except: 
            print(f"could not calc max on prop: {prop}")
        f.write(f"{'#'*10}\n")
        try:
            prop_unique_vals = np.unique(g.vertex_properties[prop])
            pickle.dump(prop_unique_vals, open(os.path.join(dir_path, f"{prop}_unique_vals"), 'wb'), protocol=5)
#             np.save(, )
        except Exception as e:
            print(f'could not find and save unique {prop} values:\n {e}')
#         np.save(os.path.join(dir_path, f"{prop}_all_vals"), g.vertex_properties[prop])
        pickle.dump(g.vertex_properties[prop].get_array(), open(os.path.join(dir_path, f"{prop}_all_vals"), 'wb'), protocol=5)
# Out:
# exploring: annotation
# could not calc mean on prop: annotation
# could not calc std on prop: annotation
# could not calc min on prop: annotation
# could not calc max on prop: annotation
# exploring: artery_binary
# could not calc mean on prop: artery_binary
# could not calc std on prop: artery_binary
# could not calc min on prop: artery_binary
# could not calc max on prop: artery_binary
# exploring: artery_raw
# could not calc mean on prop: artery_raw
# could not calc std on prop: artery_raw
# could not calc min on prop: artery_raw
# could not calc max on prop: artery_raw
# exploring: coordinates
# could not calc mean on prop: coordinates
# could not calc std on prop: coordinates
# could not calc min on prop: coordinates
# could not calc max on prop: coordinates
# exploring: coordinates_atlas
# could not calc mean on prop: coordinates_atlas
# could not calc std on prop: coordinates_atlas
# could not calc min on prop: coordinates_atlas
# could not calc max on prop: coordinates_atlas
# exploring: distance_to_surface
# could not calc mean on prop: distance_to_surface
# could not calc std on prop: distance_to_surface
# could not calc min on prop: distance_to_surface
# could not calc max on prop: distance_to_surface
# exploring: radii
# could not calc mean on prop: radii
# could not calc std on prop: radii
# could not calc min on prop: radii
# could not calc max on prop: radii
# exploring: radii_atlas
# could not calc mean on prop: radii_atlas
# could not calc std on prop: radii_atlas
# could not calc min on prop: radii_atlas
# could not calc max on prop: radii_atlas

# %%
dir_path = 'properties_exploration/edges_properties_exploration/'
os.makedirs(dir_path, exist_ok=True)
with open(os.path.join(dir_path, 'edges_properties_exploration.txt'), 'w') as f:
    for prop in ('artery', 
                 'artery_binary', 
                 'artery_raw', 
                 'distance_to_surface',
                 'edge_geometry_indices',
                 'length', 
                 'radii', 
                 'radii_atlas',
                'vein',
                'vein_big'):
        print(f"exploring: {prop}")
        f.write(f"{'#'*10}\n{prop} exploration:\n")
        try:
            prop_mean = g.edge_properties[prop].mean()
            f.write(f"{prop} mean: {prop_mean}\n")
        except: 
            print(f"could not calc mean on prop: {prop}")
        try:
            prop_std = g.edge_properties[prop].std()
            f.write(f"{prop} std: {prop_std}\n")
        except: 
            print(f"could not calc std on prop: {prop}")
        try:
            prop_min = g.edge_properties[prop].min()
            f.write(f"{prop} min: {prop_min}\n")
        except: 
            print(f"could not calc min on prop: {prop}")
        try:
            prop_max = g.edge_properties[prop].max()
            f.write(f"{prop} max: {prop_max}\n")
        except: 
            print(f"could not calc max on prop: {prop}")
        f.write(f"{'#'*10}\n")
        try:
            prop_unique_vals = np.unique(g.edge_properties[prop])
#             np.save(os.path.join(dir_path, f"{prop}_unique_vals"), prop_unique_vals)
            pickle.dump(prop_unique_vals, open(os.path.join(dir_path, f"{prop}_unique_vals"), 'wb'), protocol=5)
        except Exception as e:
            print(f'could not find and save unique {prop} values:\n {e}')
#         np.save(os.path.join(dir_path, f"{prop}_all_vals"), g.vertex_properties[prop])
        pickle.dump(g.edge_properties[prop].get_array(), open(os.path.join(dir_path, f"{prop}_all_vals"), 'wb'), protocol=5)
# Out:
# exploring: artery
# could not calc mean on prop: artery
# could not calc std on prop: artery
# could not calc min on prop: artery
# could not calc max on prop: artery
# exploring: artery_binary
# could not calc mean on prop: artery_binary
# could not calc std on prop: artery_binary
# could not calc min on prop: artery_binary
# could not calc max on prop: artery_binary
# exploring: artery_raw
# could not calc mean on prop: artery_raw
# could not calc std on prop: artery_raw
# could not calc min on prop: artery_raw
# could not calc max on prop: artery_raw
# exploring: distance_to_surface
# could not calc mean on prop: distance_to_surface
# could not calc std on prop: distance_to_surface
# could not calc min on prop: distance_to_surface
# could not calc max on prop: distance_to_surface
# exploring: edge_geometry_indices
# could not calc mean on prop: edge_geometry_indices
# could not calc std on prop: edge_geometry_indices
# could not calc min on prop: edge_geometry_indices
# could not calc max on prop: edge_geometry_indices
# exploring: length
# could not calc mean on prop: length
# could not calc std on prop: length
# could not calc min on prop: length
# could not calc max on prop: length
# exploring: radii
# could not calc mean on prop: radii
# could not calc std on prop: radii
# could not calc min on prop: radii
# could not calc max on prop: radii
# exploring: radii_atlas
# could not calc mean on prop: radii_atlas
# could not calc std on prop: radii_atlas
# could not calc min on prop: radii_atlas
# could not calc max on prop: radii_atlas
# exploring: vein_big
# could not calc mean on prop: vein_big
# could not calc std on prop: vein_big
# could not calc min on prop: vein_big
# could not calc max on prop: vein_big

# %%
job_id = '3257556'
ssd_dir_path = f'/scratch/yishaiaz@auth.ad.bgu.ac.il/{job_id}'
ssd_path_to_graph_gt = os.path.join(ssd_dir_path, 'data_graph.gt')
print('Started loading graph from SSD')
_start = datetime.datetime.now()
g = load_graph(ssd_path_to_graph_gt)
_end = datetime.datetime.now()
t = _end - _start
print(f"Finished reading the graph in {int(t.total_seconds())} seconds")
print(f"Finished reading the graph in {int(t.total_seconds()/60)} minutes")
# Out:
# Started loading graph from SSD
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 6>()
#       4 print('Started loading graph from SSD')
#       5 _start = datetime.datetime.now()
# ----> 6 g = load_graph(ssd_path_to_graph_gt)
#       7 _end = datetime.datetime.now()
#       8 t = _end - _start
#
# File ~/.conda/envs/BrainVasculatureGraphAnalysis/lib/python3.10/site-packages/graph_tool/__init__.py:3380, in load_graph(file_name, fmt, ignore_vp, ignore_ep, ignore_gp)
#    3362 """Load a graph from ``file_name`` (which can be either a string or a file-like object).
#    3363
#    3364 The format is guessed from ``file_name``, or can be specified by ``fmt``,
#    (...)
#    3377
#    3378 """
#    3379 g = Graph()
# -> 3380 g.load(file_name, fmt, ignore_vp, ignore_ep, ignore_gp)
#    3381 return g
#
# File ~/.conda/envs/BrainVasculatureGraphAnalysis/lib/python3.10/site-packages/graph_tool/__init__.py:2921, in Graph.load(self, file_name, fmt, ignore_vp, ignore_ep, ignore_gp)
#    2919     ignore_gp = []
#    2920 if isinstance(file_name, str):
# -> 2921     props = self.__graph.read_from_file(file_name, None,
#    2922                                         fmt, ignore_vp,
#    2923                                         ignore_ep, ignore_gp)
#    2924 else:
#    2925     with fctx:
#
# File ~/.conda/envs/BrainVasculatureGraphAnalysis/lib/python3.10/site-packages/graph_tool/gt_io.py:69, in unpickler(stream)
#      68 def unpickler(stream):
# ---> 69     data = stream.read()
#      70     sstream = BytesIO(data)
#      71     return pickle.load(sstream, encoding="bytes")
#
# File ~/.conda/envs/BrainVasculatureGraphAnalysis/lib/python3.10/site-packages/graph_tool/gt_io.py:35, in IStream_read(self, n, buflen)
#      33     buf = self.read_buf(buflen)
#      34     data += buf
# ---> 35     if len(buf) < buflen:
#      36         break
#      37 return data
#
# KeyboardInterrupt:

# %%
def euclidean(p1: Tuple[int, ...], p2: Tuple[int, ...]) -> float:
    return math.sqrt(reduce(lambda prev, c: prev + (c[0] - c[1]) ** 2, zip(p1, p2), 0))


def find_motifs(graph: Graph, max_motif_size: int = 10, max_visited: int = 10**5):
    # g_adj_mat = get_adjacency_matrix(g)
    visited = np.zeros(g.num_vertices(), dtype=bool)
    visited_num = 0
    v_it = g.vertices()
    simple_motifs_found = {}

    def get_motif_rec(initial_vertex, current_vertex, curr_track, curr_depth):
        # global visited_num, visited
        if curr_depth >= max_motif_size:
            return None
        curr_vertex_neighbors = sorted(graph.get_all_neighbors(current_vertex), key=lambda v: euclidean(graph.vertex_properties['coordinates'][v], graph.vertex_properties['coordinates'][current_vertex]))
        if initial_vertex in curr_vertex_neighbors and curr_depth > 1:
            return curr_track

        possible_tracks = []
        for curr_vertex_neighbor in curr_vertex_neighbors:
            if curr_vertex_neighbor == initial_vertex or curr_vertex_neighbor in curr_track:
                continue
            track = get_motif_rec(initial_vertex, curr_vertex_neighbor,
                                  curr_track + [curr_vertex_neighbor],
                                  curr_depth + 1)
            if track is None:
                continue
            else:
                possible_tracks.append(track)
        if not possible_tracks:
            return None
        else:
            return sorted(possible_tracks, key=len)[0]

    # adj_row_idx = 0
    with tqdm(total=min(max_visited, graph.num_vertices()), file=sys.stdout) as pbar:
        while visited_num < max_visited:
            pbar.set_description('processed: %d' % (1 + visited_num))
             
            try:
                initial_vertex = graph.vertex_index[next(v_it)]
                while visited[initial_vertex]:
                    initial_vertex = graph.vertex_index[next(v_it)]
            except StopIteration:
                break
            visited[initial_vertex] = True
            initial_v_neighbors = sorted(graph.get_all_neighbors(initial_vertex), key=lambda v: euclidean(graph.vertex_properties['coordinates'][v], graph.vertex_properties['coordinates'][initial_vertex]))
            for v_initial_neighbor in initial_v_neighbors:
                if visited[v_initial_neighbor]:
                    continue
                # v_initial_neighbor_neighbors = graph.get_all_neighbors(v_initial_neighbor)
                initial_v_motif = get_motif_rec(initial_vertex, v_initial_neighbor, [v_initial_neighbor], 1)
                if initial_v_motif is not None:
                    initial_v_motif += [graph.vertex_index[initial_vertex]]
                    initial_motif_len = len(initial_v_motif)
                    # MOTIFS_FOUND[initial_motif_len] += 1
                    simple_motifs_found[initial_motif_len] = simple_motifs_found.get(initial_motif_len, []) + [initial_v_motif]

                    for v_idx in initial_v_motif:
                        visited[v_idx] = True
                    visited_num += initial_motif_len
                    pbar.update(initial_motif_len) 

    return simple_motifs_found


print('Started gathering simple motifs v_indices')
max_to_visit, max_size_of_motif = float('inf'), 10
simple_motifs = find_motifs(graph=g, max_motif_size=max_size_of_motif, max_visited=max_to_visit)
pickle.dump(simple_motifs, open(os.path.join(ssd_dir_path, f"{'all_' if max_to_visit ==float('inf') else f'max_{max_to_visit}_'}simple_motifs_max_size_{max_to_visit}"), 'wb'), protocol=5)

print('Finished gathering simple motifs v_indices')
# Out:
# Started gathering simple motifs v_indices
# processed: 400132:  12%|█▏        | 400139/3449637 [55:08<9:39:37, 87.69it/s]

# %%
def get_motif_properties(graph: Graph, motif_vertices_indices: List[int],
                         edge_properties: Tuple[str] = ('length', 'radii'),
                         vertex_properties: Tuple[str] = ('coordinates', 'coordinates_atlas')):
    motif_edge_properties = {}
    motif_vertex_properties = {}
    for v_prop in vertex_properties:
        motif_vertex_properties[v_prop] = [graph.vertex_properties[v_prop][v]
                                           for v in motif_vertices_indices]
    for e_prop in edge_properties:
        motif_vertex_properties[e_prop] = [graph.edge_properties[e_prop][graph.edge(*e)]
                                           for e in itertools.combinations(motif_vertices_indices, 2) if graph.edge(*e) in graph.edges()]

    # vertices_atlas = [graph.vertex_properties['coordinates_atlas'][v] for v in motif_vertices_indices]
    # vertices_artery = [graph.vertex_properties['artery_binary'][v] for v in motif_vertices_indices]
    # edge_radiis = [graph.edge_properties['radii'][e] for e in itertools.combinations(motif_vertices_indices, 2)]
    # edge_lengths = [graph.edge_properties['length'][(motif_vertices_indices[v_idx], motif_vertices_indices[v_idx+1])] for v_idx in range(len(motif_vertices_indices[:-1]))]

    # todo: get all edges between motif vertices.
    # todo: define all spatial and morphological properties as a key for each motif.
    # todo: define spatial motifs definition as a tolerance based definition.
    return motif_edge_properties, motif_vertex_properties

motifs_with_properties = {}
print('Started gathering motifs properties')
for motif_len, motifs_v_indices in tqdm(simple_motifs.items()):
    print(f"gathering motifs' properties with len={motif_len}")
    motifs_with_properties[motif_len] = motifs_with_properties.get(motif_len, []) +\
                                        [get_motif_properties(g, motif_v_indices)
                                         for motif_v_indices in motifs_v_indices]

pickle.dump(motifs_with_properties, open(os.path.join(ssd_dir_path, f"{'all_' if max_to_visit ==float('inf') else f'max_{max_to_visit}_'}motifs_with_properties_max_size_{max_to_visit}"), 'wb'), protocol=5)
print('DONE')

# %%
list(simple_motifs.keys())
# Out:
# [5, 3, 4]
