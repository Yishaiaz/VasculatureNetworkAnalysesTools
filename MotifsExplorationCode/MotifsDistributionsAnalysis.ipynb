# %%
import os
import numpy as np
# import pandas as pd
import pickle
import shutil
from collections import Counter
import matplotlib.pyplot as plt
from graph_tool import clustering as clst
# from reportlab.pdfgen import canvas
from PyPDF2 import PdfFileWriter, PdfFileReader
from typing import *
import json
from matplotlib.offsetbox import OffsetImage,AnnotationBbox
import warnings

# %%
from graph_tool.all import *

# %% [markdown]
# # Subgraphs by annotation label analysis and visualization

# %% [markdown]
# ## simple motifs, no structural attributes

# %%
all_motifs_type_colors = {}

# %%
def remove_duplicate_motifs(motifs, motifs_cnts):
    new_motifs = {}
    for motif1, motif1_cnts in zip(motifs, motifs_cnts):
        in_flag = False
        for motif2, motif2_cnts in new_motifs.items():
            if isomorphism(motif1, motif2) and motif1 is not motif2:
                in_flag = True
                new_motifs[motif1]+=motif2_cnts
                
        if not in_flag:
            new_motifs[motif1] = motif1_cnts

    return list(new_motifs.keys()), list(new_motifs.values())


def calc_motifs_no_redundant_edges(g, motifs_len, name_to_save_by=None, dir_to_save_path=None):
    remove_parallel_edges(g)
    motifs, motifs_cnts, motifs_vertex_properties = clst.motifs(g, k=motifs_len, p=1.0, return_maps=True)
    motifs, motifs_cnts = remove_duplicate_motifs(motifs, motifs_cnts)
    motifs_dict = {
        motif: {'motif_count': cnt, 'motif_vertex_ids': single_motif_v_ids} \
        for motif, cnt, single_motif_v_ids in zip(motifs, motifs_cnts, motifs_vertex_properties)
    }
    
    if name_to_save_by is None:
        return motifs_dict
    
    if dir_to_save_path is not None:
        path_to_save_motifs_data = os.path.join(dir_to_save_path, name_to_save_by)
    else:
        path_to_save_motifs_data = name_to_save_by
    
    with open(path_to_save_motifs_data, 'wb') as f:
        pickle.dump(motifs_dict, f)
    
    return motifs_dict

def get_flag(motif_type, v_color):
    graph_draw(motif_type, output='tmp/t.png', output_size=(30, 30), vertex_fill_color=v_color)
    path = "tmp/t.png"
    im = plt.imread(path)
    return im

def offset_image(coord, motif_type, ax):
    v_color = all_motifs_type_colors[motif_type]
    img = get_flag(motif_type, v_color=v_color)
    im = OffsetImage(img, zoom=1)
    im.image.axes = ax

    ab = AnnotationBbox(im, (coord, 0),  xybox=(0., -16.), frameon=False,
                        xycoords='data',  boxcoords="offset points", pad=0)

    ax.add_artist(ab)
    
def plot_motif_cnts_per_type(motifs_types, valuesA, subgraph_name, path_to_save_plot_dir = None, motifs_len: int =4):
    """
    plots with motifs ilustration (graph_draw) as axis labels
    """
    fig, ax = plt.subplots(figsize=(30, 20))

    ax.bar(range(len(motifs_types)), valuesA, width=0.5, align="center")
    ax.set_xticks(range(len(motifs_types)))
    ax.set_xticklabels([])
    ax.tick_params(axis='x', which='major', pad=26)
    
    for bars in ax.containers:
        ax.bar_label(bars)   
        
    ax.set_title(f"{subgraph_name} counts")
    
#     plt.tight_layout()
    
    for i, motif_type in enumerate(motifs_types):
        offset_image(i, motif_type, ax)
    if path_to_save_plot_dir is None:
        plt.show()
    else:
        path_to_save_plot = os.path.join(path_to_save_plot_dir, f"{subgraph_name}_{motifs_len}.png")
        plt.savefig(path_to_save_plot, dpi=300)
        
def draw_graph_with_motifs_coloring(g, motifs_len, name_to_save_by, dir_to_save_path=None, 
                                    motifs_precalculated_dict_pickle_path: str= None):
    global all_motifs_type_colors
#     use pre calculated motifs distributions
    if motifs_precalculated_dict_pickle_path is not None:
        with open(motifs_precalculated_dict_pickle_path, 'rb') as f:
            data = pickle.load(f)
            motifs = data.keys()
            motifs_cnts, motifs_vertex_properties = [], []
            for motif in motifs:
                motifs_cnts.append(data[motif]['motif_count'])
                motifs_vertex_properties.append(data[motif]['motif_vertex_ids'])
    else:
        #     calculate motifs and aggregate all motifs vertices_ids
        motifs_dict = calc_motifs_no_redundant_edges(g, motifs_len)
        motifs, motifs_cnts, motifs_vertex_properties = [], [], []
        for motif, motif_vals in motifs_dict.items():
            motifs.append(motif)
            motifs_cnts.append(motif_vals['motif_count'])
            motifs_vertex_properties.append(motif_vals['motif_vertex_ids'])
    
    all_motifs_type_v_ids = {}
    for motif, motifs_v_ids in zip(motifs, motifs_vertex_properties): 
        single_motif_type_v_ids = []
        for single_motif_v_ids in motifs_v_ids:
            if any([type(x) is not int for x in single_motif_v_ids.a.tolist()]):
                raise Exception(f"Vertices IDs must be integers only;\n{single_motif_v_ids.a.tolist()}, {[type(x) for x in single_motif_v_ids.a.tolist()]}")
            single_motif_type_v_ids+=single_motif_v_ids.a.tolist()
        all_motifs_type_v_ids[motif] = single_motif_type_v_ids 
#         if motif type is not familiar, set up a random color, if already seen, we will use the color already assigned
        if all_motifs_type_colors.get(motif, None) is None:
            motif_type_color = list(np.random.choice(np.arange(0.3, 1., 0.1), size=3)) + [0.9]
            all_motifs_type_colors[motif] = motif_type_color
    
    g_positions = g.vp['coordinates']
    vprop_vcolor_by_motif = g.new_vertex_property("vector<double>")
#     create the color mapping for each vertex (GT propertyMap) and collect vertices coordinates
    for motif, motif_v_ids in all_motifs_type_v_ids.items():
        motif_color = all_motifs_type_colors[motif]
        for v_id in motif_v_ids:
            v = g.vertex(v_id)
            vprop_vcolor_by_motif[v_id] = motif_color
    
#     # create the color mapping for each edge (GT propertyMap)
#     eprop_ecolor_by_motif = g.new_edge_property("vector<double>")
#     for motif, motif_v_ids in all_motifs_type_v_ids.items():
#         motif_color = all_motifs_type_colors[motif]
#         for v_id in motif_v_ids:
#             v = g.vertex(v_id)
#             for edge in g.iter_all_edges(v):
#                 edge = tuple(edge)
#                 print("#"*20, "\n", f"{edge}\n","#"*20)
#                 eprop_ecolor_by_motif[edge] = motif_color

    # fill property map for vertices not in motifs:
    changed_ctr = 0
    for v in g.iter_vertices():
        if not len(vprop_vcolor_by_motif[v]):
#     assigned black color to all vertices within the subgraph that do not belong to a motif
            vprop_vcolor_by_motif[v] = [0., 0., 0., 1.]
    
#     # fill property map for edges not in motifs:
#     changed_ctr = 0
#     for v in g.iter_edges():
#         if not len(vprop_vcolor_by_motif[v]):
# #     assigned black color to all edges within the subgraph that do not belong to a motif
#             eprop_ecolor_by_motif[edge] = [0., 0., 0., 1.]
    
    
    output_fname = f"{name_to_save_by}_with_motif_{motifs_len}.pdf"
    output_dir_name = f"{name_to_save_by}" 
    dir_to_save_path_by_subgraph = os.path.join(dir_to_save_path, output_dir_name)
    
    if not os.path.isdir(dir_to_save_path_by_subgraph):
        os.makedirs(dir_to_save_path_by_subgraph)
    
    output_path = os.path.join(dir_to_save_path_by_subgraph, output_fname)
    graph_draw(g, pos=g_positions, output=output_path,
               vertex_fill_color=vprop_vcolor_by_motif,)
#                edge_color=eprop_ecolor_by_motif)
    
    output_fname = output_fname.replace('.pdf', '.png')
#     output_path = os.path.join(dir_to_save_path_by_subgraph, output_fname)
    if len(motifs) > 10:
        index = 0
        for i1, i2 in zip(range(0, len(motifs), 10), range(10, len(motifs)+9, 10)):
            motifs_tmp, motifs_cnts_tmp = motifs[i1:i2], motifs_cnts[i1:i2]
            output_fname_tmp = output_fname.replace('.png', f'_{index}.png')
            plot_motif_cnts_per_type(motifs_types=motifs_tmp, valuesA=motifs_cnts_tmp, 
                                     subgraph_name=output_fname_tmp, 
                                     path_to_save_plot_dir=dir_to_save_path_by_subgraph, 
                                     motifs_len=motifs_len)
            index += 1
    else:
        plot_motif_cnts_per_type(motifs_types=motifs, valuesA=motifs_cnts, 
                                 subgraph_name=output_fname, 
                                 path_to_save_plot_dir=dir_to_save_path_by_subgraph, 
                                 motifs_len=motifs_len)

def find_motifs_no_redundant_edges(g, motif_len, name_to_save_by=None, dir_to_save_path=None, motifs_precalculated_dict_pickle_path=None):
    remove_parallel_edges(g)
    draw_graph_with_motifs_coloring(g, motif_len, name_to_save_by, dir_to_save_path, motifs_precalculated_dict_pickle_path)

# %%
motifs_len = 4
graph_size_lim = 10**5 if motifs_len <= 6 else 10**4

# %% [markdown]
# ### calc motifs distributions

# %%
subgraphs_dir = '/scratch/mice_subgraphs/subgraphsByAnnotationLabels'
to_save_distributions_dir_path = f'/scratch/motifsDistributions/MotifDistributionsPerAnnotationPickled/MotifSize_{motifs_len}'

if not os.path.isdir(to_save_distributions_dir_path):
    os.makedirs(to_save_distributions_dir_path, exist_ok=True)

subgraphs_names = os.listdir(subgraphs_dir)

all_subgraphs_motifs_data = {}
for subgraph_name in subgraphs_names[:]:
    print(subgraph_name)    
    subgraph_path = os.path.join(subgraphs_dir, subgraph_name)
    subgraph_gt = load_graph(subgraph_path)
    if subgraph_gt.num_vertices() > graph_size_lim:
        continue
    all_subgraphs_motifs_data[subgraph_name] = calc_motifs_no_redundant_edges(subgraph_gt, motifs_len, subgraph_name, to_save_distributions_dir_path)
# Out:
# subgraph_area_vestibular nerve.gt
# subgraph_area_Inferior colliculus.gt
# subgraph_area_Olfactory areas.gt
# subgraph_area_Culmen.gt
# subgraph_area_motor root of the trigeminal nerve.gt
# subgraph_area_Pyramus (VIII).gt
# subgraph_area_lateral lemniscus.gt
# subgraph_area_Simple lobule.gt
# subgraph_area_universe.gt
# subgraph_area_Midbrain reticular nucleus, retrorubral area.gt
# subgraph_area_mammillotegmental tract.gt
# subgraph_area_lateral ventricle.gt
# subgraph_area_spinal tract of the trigeminal nerve.gt
# subgraph_area_Trochlear nucleus.gt
# subgraph_area_Ansiform lobule.gt
# subgraph_area_Lingula (I).gt
# subgraph_area_Basic cell groups and regions.gt
# subgraph_area_cerebal peduncle.gt
# subgraph_area_Parabigeminal nucleus.gt
# subgraph_area_Midbrain.gt
# subgraph_area_Flocculus.gt
# subgraph_area_arbor vitae.gt
# subgraph_area_Declive (VI).gt
# subgraph_area_habenular commissure.gt
# subgraph_area_Substantia nigra, compact part.gt
# subgraph_area_inferior colliculus commissure.gt
# subgraph_area_Copula pyramidis.gt
# subgraph_area_Dentate nucleus.gt
# subgraph_area_Striatum-like amygdalar nuclei.gt
# subgraph_area_third ventricle.gt
# subgraph_area_Hypothalamus.gt
# subgraph_area_anterior commissure, temporal limb.gt
# subgraph_area_internal medullary lamina of the thalamus.gt
# subgraph_area_fasciculus retroflexus.gt
# subgraph_area_cingulum bundle.gt
# subgraph_area_Lateral amygdalar nucleus.gt
# subgraph_area_facial nerve.gt
# subgraph_area_Folium-tuber vermis (VII).gt
# subgraph_area_optic chiasm.gt
# subgraph_area_Oculomotor nucleus.gt
# subgraph_area_doral tegmental decussation.gt
# subgraph_area_ventral tegmental decussation.gt
# subgraph_area_Nucleus sagulum.gt
# subgraph_area_Central lobule.gt
# subgraph_area_pyramid.gt
# subgraph_area_inferior cerebellar peduncle.gt
# subgraph_area_Ventral tegmental area.gt
# subgraph_area_tectospinal pathway.gt
# subgraph_area_lateral recess.gt
# subgraph_area_principal mammillary tract.gt
# subgraph_area_Red nucleus.gt
# subgraph_area_fimbria.gt
# subgraph_area_Cortical subplate.gt
# subgraph_area_posterior commissure.gt
# subgraph_area_Isocortex.gt
# subgraph_area_Hippocampal formation.gt
# subgraph_area_Periaqueductal gray.gt
# subgraph_area_Midbrain reticular nucleus.gt
# subgraph_area_Posterior amygdalar nucleus.gt
# subgraph_area_olfactory nerve layer of main olfactory bulb.gt
# subgraph_area_Thalamus.gt
# subgraph_area_corticospinal tract.gt
# subgraph_area_corpus callosum.gt
# subgraph_area_Pons.gt
# subgraph_area_anterior commissure, olfactory limb.gt
# subgraph_area_Anterior tegmental nucleus.gt
# subgraph_area_Nodulus (X).gt
# subgraph_area_superior cerebelar peduncles.gt
# subgraph_area_dorsal fornix.gt
# subgraph_area_Interposed nucleus.gt
# subgraph_area_Cuneiform nucleus.gt
# subgraph_area_ventricular systems.gt
# subgraph_area_middle cerebellar peduncle.gt
# subgraph_area_optic tract.gt
# subgraph_area_Pallidum.gt
# subgraph_area_medial lemniscus.gt
# subgraph_area_trapezoid body.gt
# subgraph_area_Claustrum.gt
# subgraph_area_stria terminalis.gt
# subgraph_area_external medullary lamina of the thalamus.gt
# subgraph_area_midbrain tract of the trigeminal nerve.gt
# subgraph_area_Lateral terminal nucleus of the accessory optic tract.gt
# subgraph_area_amygdalar capsule.gt
# subgraph_area_Basomedial amygdalar nucleus.gt

# %% [markdown]
# ## calc motif z score significance

# %%
def is_isomorphic_motif(motif_1, motif2_group):
    for motif2 in motif2_group:
        if isomorphism(motif1, motif2):
            return True
    return False
                
def calc_motif_z_score(motif_n_target: int, motif_n_random_networks: np.array, significance_threshold: float = 2.0):
    random_sigma = motif_n_random_networks.std()
    z_score = (motif_n_target - motif_n_random_networks.mean())/random_sigma
    is_significant = z_score > significance_threshold
    return z_score, is_significant


def rewire_subgraph_and_calc_motifs_of_random(subgraph, motifs_len_to_compare:int = 4, **kwargs):
    subgraph_to_shuffle = subgraph.copy()
    random_rewire(subgraph_to_shuffle, model=kwargs.get('shuffle_model', 'configuration'),
                  n_iter=kwargs.get('shuffle_iters', 1),
                  edge_sweep=kwargs.get('shuffle_edge_sweep', True),
                  parallel_edges=kwargs.get('shuffle_parallel_edges', False))
    shuffled_motif_dist = calc_motifs_no_redundant_edges(subgraph_to_shuffle, motifs_len_to_compare)
    return shuffled_motif_dist

def motifs_z_scores_calculation(org_graph, 
                                org_graph_motifs_dict, 
                                motifs_len_to_compare:int = 4, 
                                n_random_graphs_to_generate: int = 1000, 
                                **kwargs):
    graph_cpy = org_graph.copy()
    motifs_counts_in_random_graph = {}
    print(f'Started generating {n_random_graphs_to_generate} random graphs:')
    for i in range(n_random_graphs_to_generate):
        print(f'Generating random graph {i+1}/{n_random_graphs_to_generate}')
        rand_graph_motifs_dist = rewire_subgraph_and_calc_motifs_of_random(graph_cpy, 
                                                                           motifs_len_to_compare, 
                                                                           **kwargs)
        for motif, motif_dict in rand_graph_motifs_dist.items():
            motifs_counts_in_random_graph[motif] = motifs_counts_in_random_graph.get(motif, []) + [motif_dict['motif_count']]
    print(f'Started calculating motifs z-scores:')
    motifs_z_scores = {}
    for motif, motif_dict in motifs_counts_in_random_graph.items():
        motif_n_target = None
        for org_motif in org_graph_motifs_dict.keys():
            if isomorphism(org_motif, motif):
                motif_n_target = org_graph_motifs_dict[org_motif]['motif_count']
        if motif_n_target is None:
            warnings.warn(f"Motif {motif} was not found in the original graph, skipping")
            continue
        motif_counts_in_random_network_nparray = np.array(motifs_counts_in_random_graph[motif])
        motifs_z_scores[motif] = calc_motif_z_score(motif_n_target=motif_n_target,
                                                    motif_n_random_networks=motif_counts_in_random_network_nparray,
                                                   significance_threshold=kwargs.get('z_score_significance_threshold', 2))
    return motifs_z_scores

# %% [markdown]
# ### examples for z-score significance calculation for Ph.D. proposal

# %%
motifs_len = 4
precalc_pickled_distributions_dir_path = f'/scratch/motifsDistributions/MotifDistributionsPerAnnotationPickled/MotifSize_{motifs_len}'
subgraphs_dir = '/scratch/mice_subgraphs/subgraphsByAnnotationLabels'
all_subgraphs_in_dir = os.listdir(subgraphs_dir)
phd_prop_subgraphs_names = list(filter(lambda subgraph_name: 
                                 any([target_name.lower() in subgraph_name.lower() for target_name in ('Cuneiform Nucleus', 'Fasciculus Retroflexus')]), 
                                      all_subgraphs_in_dir))
phd_prop_subgraphs_paths = list(map(lambda x: os.path.join(subgraphs_dir, x), phd_prop_subgraphs_names))
phd_prop_subgraphs_gt = {sub_name: load_graph(sub_path) for sub_name, sub_path in 
                         zip(phd_prop_subgraphs_names, phd_prop_subgraphs_paths)}

# %%
subgraphs_motifs = {}
subgraphs_motifs_stats = {}

for sub_name, sub_gt in phd_prop_subgraphs_gt.items():
    subgraphs_motifs[sub_name] = calc_motifs_no_redundant_edges(g=sub_gt, motifs_len=motifs_len)

# %%
subgraph_motifs_zscores = {}
for sub_name, sub_motifs_dict in subgraphs_motifs.items():
    subgraph_motifs_zscores[sub_name] = {}
    subgraph_motifs_zscores[sub_name]['motifs_zscores'] = motifs_z_scores_calculation(
        org_graph=phd_prop_subgraphs_gt[sub_name], 
        org_graph_motifs_dict=sub_motifs_dict, 
        motifs_len_to_compare=4, 
        n_random_graphs_to_generate=1000,
        z_score_significance_threshold=2.0
    )
# Out:
# Started generating 1000 random graphs:
# Generating random graph 1/1000
# Generating random graph 2/1000
# Generating random graph 3/1000
# Generating random graph 4/1000
# Generating random graph 5/1000
# Generating random graph 6/1000
# Generating random graph 7/1000
# Generating random graph 8/1000
# Generating random graph 9/1000
# Generating random graph 10/1000
# Generating random graph 11/1000
# Generating random graph 12/1000
# Generating random graph 13/1000
# Generating random graph 14/1000
# Generating random graph 15/1000
# Generating random graph 16/1000
# Generating random graph 17/1000
# Generating random graph 18/1000
# Generating random graph 19/1000
# Generating random graph 20/1000
# Generating random graph 21/1000
# Generating random graph 22/1000
# Generating random graph 23/1000
# Generating random graph 24/1000
# Generating random graph 25/1000
# Generating random graph 26/1000
# Generating random graph 27/1000
# Generating random graph 28/1000
# Generating random graph 29/1000
# Generating random graph 30/1000
# Generating random graph 31/1000
# Generating random graph 32/1000
# Generating random graph 33/1000
# Generating random graph 34/1000
# Generating random graph 35/1000
# Generating random graph 36/1000
# Generating random graph 37/1000
# Generating random graph 38/1000
# Generating random graph 39/1000
# Generating random graph 40/1000
# Generating random graph 41/1000
# Generating random graph 42/1000
# Generating random graph 43/1000
# Generating random graph 44/1000
# Generating random graph 45/1000
# Generating random graph 46/1000
# Generating random graph 47/1000
# Generating random graph 48/1000
# Generating random graph 49/1000
# Generating random graph 50/1000
# Generating random graph 51/1000
# Generating random graph 52/1000
# Generating random graph 53/1000
# Generating random graph 54/1000
# Generating random graph 55/1000
# Generating random graph 56/1000
# Generating random graph 57/1000
# Generating random graph 58/1000
# Generating random graph 59/1000
# Generating random graph 60/1000
# Generating random graph 61/1000
# Generating random graph 62/1000
# Generating random graph 63/1000
# Generating random graph 64/1000
# Generating random graph 65/1000
# Generating random graph 66/1000
# Generating random graph 67/1000
# Generating random graph 68/1000
# Generating random graph 69/1000
# Generating random graph 70/1000
# Generating random graph 71/1000
# Generating random graph 72/1000
# Generating random graph 73/1000
# Generating random graph 74/1000
# Generating random graph 75/1000
# Generating random graph 76/1000
# Generating random graph 77/1000
# Generating random graph 78/1000
# Generating random graph 79/1000
# Generating random graph 80/1000
# Generating random graph 81/1000
# Generating random graph 82/1000
# Generating random graph 83/1000
# Generating random graph 84/1000
# Generating random graph 85/1000
# Generating random graph 86/1000
# Generating random graph 87/1000
# Generating random graph 88/1000
# Generating random graph 89/1000
# Generating random graph 90/1000
# Generating random graph 91/1000
# Generating random graph 92/1000
# Generating random graph 93/1000
# Generating random graph 94/1000
# Generating random graph 95/1000
# Generating random graph 96/1000
# Generating random graph 97/1000
# Generating random graph 98/1000
# Generating random graph 99/1000
# Generating random graph 100/1000
# Generating random graph 101/1000
# Generating random graph 102/1000
# Generating random graph 103/1000
# Generating random graph 104/1000
# Generating random graph 105/1000
# Generating random graph 106/1000
# Generating random graph 107/1000
# Generating random graph 108/1000
# Generating random graph 109/1000
# Generating random graph 110/1000
# Generating random graph 111/1000
# Generating random graph 112/1000
# Generating random graph 113/1000
# Generating random graph 114/1000
# Generating random graph 115/1000
# Generating random graph 116/1000
# Generating random graph 117/1000
# Generating random graph 118/1000
# Generating random graph 119/1000
# Generating random graph 120/1000
# Generating random graph 121/1000
# Generating random graph 122/1000
# Generating random graph 123/1000
# Generating random graph 124/1000
# Generating random graph 125/1000
# Generating random graph 126/1000
# Generating random graph 127/1000
# Generating random graph 128/1000
# Generating random graph 129/1000
# Generating random graph 130/1000
# Generating random graph 131/1000
# Generating random graph 132/1000
# Generating random graph 133/1000
# Generating random graph 134/1000
# Generating random graph 135/1000
# Generating random graph 136/1000
# Generating random graph 137/1000
# Generating random graph 138/1000
# Generating random graph 139/1000
# Generating random graph 140/1000
# Generating random graph 141/1000
# Generating random graph 142/1000
# Generating random graph 143/1000
# Generating random graph 144/1000
# Generating random graph 145/1000
# Generating random graph 146/1000
# Generating random graph 147/1000
# Generating random graph 148/1000
# Generating random graph 149/1000
# Generating random graph 150/1000
# Generating random graph 151/1000
# Generating random graph 152/1000
# Generating random graph 153/1000
# Generating random graph 154/1000
# Generating random graph 155/1000
# Generating random graph 156/1000
# Generating random graph 157/1000
# Generating random graph 158/1000
# Generating random graph 159/1000
# Generating random graph 160/1000
# Generating random graph 161/1000
# Generating random graph 162/1000
# Generating random graph 163/1000
# Generating random graph 164/1000
# Generating random graph 165/1000
# Generating random graph 166/1000
# Generating random graph 167/1000
# Generating random graph 168/1000
# Generating random graph 169/1000
# Generating random graph 170/1000
# Generating random graph 171/1000
# Generating random graph 172/1000
# Generating random graph 173/1000
# Generating random graph 174/1000
# Generating random graph 175/1000
# Generating random graph 176/1000
# Generating random graph 177/1000
# Generating random graph 178/1000
# Generating random graph 179/1000
# Generating random graph 180/1000
# Generating random graph 181/1000
# Generating random graph 182/1000
# Generating random graph 183/1000
# Generating random graph 184/1000
# Generating random graph 185/1000
# Generating random graph 186/1000
# Generating random graph 187/1000
# Generating random graph 188/1000
# Generating random graph 189/1000
# Generating random graph 190/1000
# Generating random graph 191/1000
# Generating random graph 192/1000
# Generating random graph 193/1000
# Generating random graph 194/1000
# Generating random graph 195/1000
# Generating random graph 196/1000
# Generating random graph 197/1000
# Generating random graph 198/1000
# Generating random graph 199/1000
# Generating random graph 200/1000
# Generating random graph 201/1000
# Generating random graph 202/1000
# Generating random graph 203/1000
# Generating random graph 204/1000
# Generating random graph 205/1000
# Generating random graph 206/1000
# Generating random graph 207/1000
# Generating random graph 208/1000
# Generating random graph 209/1000
# Generating random graph 210/1000
# Generating random graph 211/1000
# Generating random graph 212/1000
# Generating random graph 213/1000
# Generating random graph 214/1000
# Generating random graph 215/1000
# Generating random graph 216/1000
# Generating random graph 217/1000
# Generating random graph 218/1000
# Generating random graph 219/1000
# Generating random graph 220/1000
# Generating random graph 221/1000
# Generating random graph 222/1000
# Generating random graph 223/1000
# Generating random graph 224/1000
# Generating random graph 225/1000
# Generating random graph 226/1000
# Generating random graph 227/1000
# Generating random graph 228/1000
# Generating random graph 229/1000
# Generating random graph 230/1000
# Generating random graph 231/1000
# Generating random graph 232/1000
# Generating random graph 233/1000
# Generating random graph 234/1000
# Generating random graph 235/1000
# Generating random graph 236/1000
# Generating random graph 237/1000
# Generating random graph 238/1000
# Generating random graph 239/1000
# Generating random graph 240/1000
# Generating random graph 241/1000
# Generating random graph 242/1000
# Generating random graph 243/1000
# Generating random graph 244/1000
# Generating random graph 245/1000
# Generating random graph 246/1000
# Generating random graph 247/1000
# Generating random graph 248/1000
# Generating random graph 249/1000
# Generating random graph 250/1000
# Generating random graph 251/1000
# Generating random graph 252/1000
# Generating random graph 253/1000
# Generating random graph 254/1000
# Generating random graph 255/1000
# Generating random graph 256/1000
# Generating random graph 257/1000
# Generating random graph 258/1000
# Generating random graph 259/1000
# Generating random graph 260/1000
# Generating random graph 261/1000
# Generating random graph 262/1000
# Generating random graph 263/1000
# Generating random graph 264/1000
# Generating random graph 265/1000
# Generating random graph 266/1000
# Generating random graph 267/1000
# Generating random graph 268/1000
# Generating random graph 269/1000
# Generating random graph 270/1000
# Generating random graph 271/1000
# Generating random graph 272/1000
# Generating random graph 273/1000
# Generating random graph 274/1000
# Generating random graph 275/1000
# Generating random graph 276/1000
# Generating random graph 277/1000
# Generating random graph 278/1000
# Generating random graph 279/1000
# Generating random graph 280/1000
# Generating random graph 281/1000
# Generating random graph 282/1000
# Generating random graph 283/1000
# Generating random graph 284/1000
# Generating random graph 285/1000
# Generating random graph 286/1000
# Generating random graph 287/1000
# Generating random graph 288/1000
# Generating random graph 289/1000
# Generating random graph 290/1000
# Generating random graph 291/1000
# Generating random graph 292/1000
# Generating random graph 293/1000
# Generating random graph 294/1000
# Generating random graph 295/1000
# Generating random graph 296/1000
# Generating random graph 297/1000
# Generating random graph 298/1000
# Generating random graph 299/1000
# Generating random graph 300/1000
# Generating random graph 301/1000
# Generating random graph 302/1000
# Generating random graph 303/1000
# Generating random graph 304/1000
# Generating random graph 305/1000
# Generating random graph 306/1000
# Generating random graph 307/1000
# Generating random graph 308/1000
# Generating random graph 309/1000
# Generating random graph 310/1000
# Generating random graph 311/1000
# Generating random graph 312/1000
# Generating random graph 313/1000
# Generating random graph 314/1000
# Generating random graph 315/1000
# Generating random graph 316/1000
# Generating random graph 317/1000
# Generating random graph 318/1000
# Generating random graph 319/1000
# Generating random graph 320/1000
# Generating random graph 321/1000
# Generating random graph 322/1000
# Generating random graph 323/1000
# Generating random graph 324/1000
# Generating random graph 325/1000
# Generating random graph 326/1000
# Generating random graph 327/1000
# Generating random graph 328/1000
# Generating random graph 329/1000
# Generating random graph 330/1000
# Generating random graph 331/1000
# Generating random graph 332/1000
# Generating random graph 333/1000
# Generating random graph 334/1000
# Generating random graph 335/1000
# Generating random graph 336/1000
# Generating random graph 337/1000
# Generating random graph 338/1000
# Generating random graph 339/1000
# Generating random graph 340/1000
# Generating random graph 341/1000
# Generating random graph 342/1000
# Generating random graph 343/1000
# Generating random graph 344/1000
# Generating random graph 345/1000
# Generating random graph 346/1000
# Generating random graph 347/1000
# Generating random graph 348/1000
# Generating random graph 349/1000
# Generating random graph 350/1000
# Generating random graph 351/1000
# Generating random graph 352/1000
# Generating random graph 353/1000
# Generating random graph 354/1000
# Generating random graph 355/1000
# Generating random graph 356/1000
# Generating random graph 357/1000
# Generating random graph 358/1000
# Generating random graph 359/1000
# Generating random graph 360/1000
# Generating random graph 361/1000
# Generating random graph 362/1000
# Generating random graph 363/1000
# Generating random graph 364/1000
# Generating random graph 365/1000
# Generating random graph 366/1000
# Generating random graph 367/1000
# Generating random graph 368/1000
# Generating random graph 369/1000
# Generating random graph 370/1000
# Generating random graph 371/1000
# Generating random graph 372/1000
# Generating random graph 373/1000
# Generating random graph 374/1000
# Generating random graph 375/1000
# Generating random graph 376/1000
# Generating random graph 377/1000
# Generating random graph 378/1000
# Generating random graph 379/1000
# Generating random graph 380/1000
# Generating random graph 381/1000
# Generating random graph 382/1000
# Generating random graph 383/1000
# Generating random graph 384/1000
# Generating random graph 385/1000
# Generating random graph 386/1000
# Generating random graph 387/1000
# Generating random graph 388/1000
# Generating random graph 389/1000
# Generating random graph 390/1000
# Generating random graph 391/1000
# Generating random graph 392/1000
# Generating random graph 393/1000
# Generating random graph 394/1000
# Generating random graph 395/1000
# Generating random graph 396/1000
# Generating random graph 397/1000
# Generating random graph 398/1000
# Generating random graph 399/1000
# Generating random graph 400/1000
# Generating random graph 401/1000
# Generating random graph 402/1000
# Generating random graph 403/1000
# Generating random graph 404/1000
# Generating random graph 405/1000
# Generating random graph 406/1000
# Generating random graph 407/1000
# Generating random graph 408/1000
# Generating random graph 409/1000
# Generating random graph 410/1000
# Generating random graph 411/1000
# Generating random graph 412/1000
# Generating random graph 413/1000
# Generating random graph 414/1000
# Generating random graph 415/1000
# Generating random graph 416/1000
# Generating random graph 417/1000
# Generating random graph 418/1000
# Generating random graph 419/1000
# Generating random graph 420/1000
# Generating random graph 421/1000
# Generating random graph 422/1000
# Generating random graph 423/1000
# Generating random graph 424/1000
# Generating random graph 425/1000
# Generating random graph 426/1000
# Generating random graph 427/1000
# Generating random graph 428/1000
# Generating random graph 429/1000
# Generating random graph 430/1000
# Generating random graph 431/1000
# Generating random graph 432/1000
# Generating random graph 433/1000
# Generating random graph 434/1000
# Generating random graph 435/1000
# Generating random graph 436/1000
# Generating random graph 437/1000
# Generating random graph 438/1000
# Generating random graph 439/1000
# Generating random graph 440/1000
# Generating random graph 441/1000
# Generating random graph 442/1000
# Generating random graph 443/1000
# Generating random graph 444/1000
# Generating random graph 445/1000
# Generating random graph 446/1000
# Generating random graph 447/1000
# Generating random graph 448/1000
# Generating random graph 449/1000
# Generating random graph 450/1000
# Generating random graph 451/1000
# Generating random graph 452/1000
# Generating random graph 453/1000
# Generating random graph 454/1000
# Generating random graph 455/1000
# Generating random graph 456/1000
# Generating random graph 457/1000
# Generating random graph 458/1000
# Generating random graph 459/1000
# Generating random graph 460/1000
# Generating random graph 461/1000
# Generating random graph 462/1000
# Generating random graph 463/1000
# Generating random graph 464/1000
# Generating random graph 465/1000
# Generating random graph 466/1000
# Generating random graph 467/1000
# Generating random graph 468/1000
# Generating random graph 469/1000
# Generating random graph 470/1000
# Generating random graph 471/1000
# Generating random graph 472/1000
# Generating random graph 473/1000
# Generating random graph 474/1000
# Generating random graph 475/1000
# Generating random graph 476/1000
# Generating random graph 477/1000
# Generating random graph 478/1000
# Generating random graph 479/1000
# Generating random graph 480/1000
# Generating random graph 481/1000
# Generating random graph 482/1000
# Generating random graph 483/1000
# Generating random graph 484/1000
# Generating random graph 485/1000
# Generating random graph 486/1000
# Generating random graph 487/1000
# Generating random graph 488/1000
# Generating random graph 489/1000
# Generating random graph 490/1000
# Generating random graph 491/1000
# Generating random graph 492/1000
# Generating random graph 493/1000
# Generating random graph 494/1000
# Generating random graph 495/1000
# Generating random graph 496/1000
# Generating random graph 497/1000
# Generating random graph 498/1000
# Generating random graph 499/1000
# Generating random graph 500/1000
# Generating random graph 501/1000
# Generating random graph 502/1000
# Generating random graph 503/1000
# Generating random graph 504/1000
# Generating random graph 505/1000
# Generating random graph 506/1000
# Generating random graph 507/1000
# Generating random graph 508/1000
# Generating random graph 509/1000
# Generating random graph 510/1000
# Generating random graph 511/1000
# Generating random graph 512/1000
# Generating random graph 513/1000
# Generating random graph 514/1000
# Generating random graph 515/1000
# Generating random graph 516/1000
# Generating random graph 517/1000
# Generating random graph 518/1000
# Generating random graph 519/1000
# Generating random graph 520/1000
# Generating random graph 521/1000
# Generating random graph 522/1000
# Generating random graph 523/1000
# Generating random graph 524/1000
# Generating random graph 525/1000
# Generating random graph 526/1000
# Generating random graph 527/1000
# Generating random graph 528/1000
# Generating random graph 529/1000
# Generating random graph 530/1000
# Generating random graph 531/1000
# Generating random graph 532/1000
# Generating random graph 533/1000
# Generating random graph 534/1000
# Generating random graph 535/1000
# Generating random graph 536/1000
# Generating random graph 537/1000
# Generating random graph 538/1000
# Generating random graph 539/1000
# Generating random graph 540/1000
# Generating random graph 541/1000
# Generating random graph 542/1000
# Generating random graph 543/1000
# Generating random graph 544/1000
# Generating random graph 545/1000
# Generating random graph 546/1000
# Generating random graph 547/1000
# Generating random graph 548/1000
# Generating random graph 549/1000
# Generating random graph 550/1000
# Generating random graph 551/1000
# Generating random graph 552/1000
# Generating random graph 553/1000
# Generating random graph 554/1000
# Generating random graph 555/1000
# Generating random graph 556/1000
# Generating random graph 557/1000
# Generating random graph 558/1000
# Generating random graph 559/1000
# Generating random graph 560/1000
# Generating random graph 561/1000
# Generating random graph 562/1000
# Generating random graph 563/1000
# Generating random graph 564/1000
# Generating random graph 565/1000
# Generating random graph 566/1000
# Generating random graph 567/1000
# Generating random graph 568/1000
# Generating random graph 569/1000
# Generating random graph 570/1000
# Generating random graph 571/1000
# Generating random graph 572/1000
# Generating random graph 573/1000
# Generating random graph 574/1000
# Generating random graph 575/1000
# Generating random graph 576/1000
# Generating random graph 577/1000
# Generating random graph 578/1000
# Generating random graph 579/1000
# Generating random graph 580/1000
# Generating random graph 581/1000
# Generating random graph 582/1000
# Generating random graph 583/1000
# Generating random graph 584/1000
# Generating random graph 585/1000
# Generating random graph 586/1000
# Generating random graph 587/1000
# Generating random graph 588/1000
# Generating random graph 589/1000
# Generating random graph 590/1000
# Generating random graph 591/1000
# Generating random graph 592/1000
# Generating random graph 593/1000
# Generating random graph 594/1000
# Generating random graph 595/1000
# Generating random graph 596/1000
# Generating random graph 597/1000
# Generating random graph 598/1000
# Generating random graph 599/1000
# Generating random graph 600/1000
# Generating random graph 601/1000
# Generating random graph 602/1000
# Generating random graph 603/1000
# Generating random graph 604/1000
# Generating random graph 605/1000
# Generating random graph 606/1000
# Generating random graph 607/1000
# Generating random graph 608/1000
# Generating random graph 609/1000
# Generating random graph 610/1000
# Generating random graph 611/1000
# Generating random graph 612/1000
# Generating random graph 613/1000
# Generating random graph 614/1000
# Generating random graph 615/1000
# Generating random graph 616/1000
# Generating random graph 617/1000
# Generating random graph 618/1000
# Generating random graph 619/1000
# Generating random graph 620/1000
# Generating random graph 621/1000
# Generating random graph 622/1000
# Generating random graph 623/1000
# Generating random graph 624/1000
# Generating random graph 625/1000
# Generating random graph 626/1000
# Generating random graph 627/1000
# Generating random graph 628/1000
# Generating random graph 629/1000
# Generating random graph 630/1000
# Generating random graph 631/1000
# Generating random graph 632/1000
# Generating random graph 633/1000
# Generating random graph 634/1000
# Generating random graph 635/1000
# Generating random graph 636/1000
# Generating random graph 637/1000
# Generating random graph 638/1000
# Generating random graph 639/1000
# Generating random graph 640/1000
# Generating random graph 641/1000
# Generating random graph 642/1000
# Generating random graph 643/1000
# Generating random graph 644/1000
# Generating random graph 645/1000
# Generating random graph 646/1000
# Generating random graph 647/1000
# Generating random graph 648/1000
# Generating random graph 649/1000
# Generating random graph 650/1000
# Generating random graph 651/1000
# Generating random graph 652/1000
# Generating random graph 653/1000
# Generating random graph 654/1000
# Generating random graph 655/1000
# Generating random graph 656/1000
# Generating random graph 657/1000
# Generating random graph 658/1000
# Generating random graph 659/1000
# Generating random graph 660/1000
# Generating random graph 661/1000
# Generating random graph 662/1000
# Generating random graph 663/1000
# Generating random graph 664/1000
# Generating random graph 665/1000
# Generating random graph 666/1000
# Generating random graph 667/1000
# Generating random graph 668/1000
# Generating random graph 669/1000
# Generating random graph 670/1000
# Generating random graph 671/1000
# Generating random graph 672/1000
# Generating random graph 673/1000
# Generating random graph 674/1000
# Generating random graph 675/1000
# Generating random graph 676/1000
# Generating random graph 677/1000
# Generating random graph 678/1000
# Generating random graph 679/1000
# Generating random graph 680/1000
# Generating random graph 681/1000
# Generating random graph 682/1000
# Generating random graph 683/1000
# Generating random graph 684/1000
# Generating random graph 685/1000
# Generating random graph 686/1000
# Generating random graph 687/1000
# Generating random graph 688/1000
# Generating random graph 689/1000
# Generating random graph 690/1000
# Generating random graph 691/1000
# Generating random graph 692/1000
# Generating random graph 693/1000
# Generating random graph 694/1000
# Generating random graph 695/1000
# Generating random graph 696/1000
# Generating random graph 697/1000
# Generating random graph 698/1000
# Generating random graph 699/1000
# Generating random graph 700/1000
# Generating random graph 701/1000
# Generating random graph 702/1000
# Generating random graph 703/1000
# Generating random graph 704/1000
# Generating random graph 705/1000
# Generating random graph 706/1000
# Generating random graph 707/1000
# Generating random graph 708/1000
# Generating random graph 709/1000
# Generating random graph 710/1000
# Generating random graph 711/1000
# Generating random graph 712/1000
# Generating random graph 713/1000
# Generating random graph 714/1000
# Generating random graph 715/1000
# Generating random graph 716/1000
# Generating random graph 717/1000
# Generating random graph 718/1000
# Generating random graph 719/1000
# Generating random graph 720/1000
# Generating random graph 721/1000
# Generating random graph 722/1000
# Generating random graph 723/1000
# Generating random graph 724/1000
# Generating random graph 725/1000
# Generating random graph 726/1000
# Generating random graph 727/1000
# Generating random graph 728/1000
# Generating random graph 729/1000
# Generating random graph 730/1000
# Generating random graph 731/1000
# Generating random graph 732/1000
# Generating random graph 733/1000
# Generating random graph 734/1000
# Generating random graph 735/1000
# Generating random graph 736/1000
# Generating random graph 737/1000
# Generating random graph 738/1000
# Generating random graph 739/1000
# Generating random graph 740/1000
# Generating random graph 741/1000
# Generating random graph 742/1000
# Generating random graph 743/1000
# Generating random graph 744/1000
# Generating random graph 745/1000
# Generating random graph 746/1000
# Generating random graph 747/1000
# Generating random graph 748/1000
# Generating random graph 749/1000
# Generating random graph 750/1000
# Generating random graph 751/1000
# Generating random graph 752/1000
# Generating random graph 753/1000
# Generating random graph 754/1000
# Generating random graph 755/1000
# Generating random graph 756/1000
# Generating random graph 757/1000
# Generating random graph 758/1000
# Generating random graph 759/1000
# Generating random graph 760/1000
# Generating random graph 761/1000
# Generating random graph 762/1000
# Generating random graph 763/1000
# Generating random graph 764/1000
# Generating random graph 765/1000
# Generating random graph 766/1000
# Generating random graph 767/1000
# Generating random graph 768/1000
# Generating random graph 769/1000
# Generating random graph 770/1000
# Generating random graph 771/1000
# Generating random graph 772/1000
# Generating random graph 773/1000
# Generating random graph 774/1000
# Generating random graph 775/1000
# Generating random graph 776/1000
# Generating random graph 777/1000
# Generating random graph 778/1000
# Generating random graph 779/1000
# Generating random graph 780/1000
# Generating random graph 781/1000
# Generating random graph 782/1000
# Generating random graph 783/1000
# Generating random graph 784/1000
# Generating random graph 785/1000
# Generating random graph 786/1000
# Generating random graph 787/1000
# Generating random graph 788/1000
# Generating random graph 789/1000
# Generating random graph 790/1000
# Generating random graph 791/1000
# Generating random graph 792/1000
# Generating random graph 793/1000
# Generating random graph 794/1000
# Generating random graph 795/1000
# Generating random graph 796/1000
# Generating random graph 797/1000
# Generating random graph 798/1000
# Generating random graph 799/1000
# Generating random graph 800/1000
# Generating random graph 801/1000
# Generating random graph 802/1000
# Generating random graph 803/1000
# Generating random graph 804/1000
# Generating random graph 805/1000
# Generating random graph 806/1000
# Generating random graph 807/1000
# Generating random graph 808/1000
# Generating random graph 809/1000
# Generating random graph 810/1000
# Generating random graph 811/1000
# Generating random graph 812/1000
# Generating random graph 813/1000
# Generating random graph 814/1000
# Generating random graph 815/1000
# Generating random graph 816/1000
# Generating random graph 817/1000
# Generating random graph 818/1000
# Generating random graph 819/1000
# Generating random graph 820/1000
# Generating random graph 821/1000
# Generating random graph 822/1000
# Generating random graph 823/1000
# Generating random graph 824/1000
# Generating random graph 825/1000
# Generating random graph 826/1000
# Generating random graph 827/1000
# Generating random graph 828/1000
# Generating random graph 829/1000
# Generating random graph 830/1000
# Generating random graph 831/1000
# Generating random graph 832/1000
# Generating random graph 833/1000
# Generating random graph 834/1000
# Generating random graph 835/1000
# Generating random graph 836/1000
# Generating random graph 837/1000
# Generating random graph 838/1000
# Generating random graph 839/1000
# Generating random graph 840/1000
# Generating random graph 841/1000
# Generating random graph 842/1000
# Generating random graph 843/1000
# Generating random graph 844/1000
# Generating random graph 845/1000
# Generating random graph 846/1000
# Generating random graph 847/1000
# Generating random graph 848/1000
# Generating random graph 849/1000
# Generating random graph 850/1000
# Generating random graph 851/1000
# Generating random graph 852/1000
# Generating random graph 853/1000
# Generating random graph 854/1000
# Generating random graph 855/1000
# Generating random graph 856/1000
# Generating random graph 857/1000
# Generating random graph 858/1000
# Generating random graph 859/1000
# Generating random graph 860/1000
# Generating random graph 861/1000
# Generating random graph 862/1000
# Generating random graph 863/1000
# Generating random graph 864/1000
# Generating random graph 865/1000
# Generating random graph 866/1000
# Generating random graph 867/1000
# Generating random graph 868/1000
# Generating random graph 869/1000
# Generating random graph 870/1000
# Generating random graph 871/1000
# Generating random graph 872/1000
# Generating random graph 873/1000
# Generating random graph 874/1000
# Generating random graph 875/1000
# Generating random graph 876/1000
# Generating random graph 877/1000
# Generating random graph 878/1000
# Generating random graph 879/1000
# Generating random graph 880/1000
# Generating random graph 881/1000
# Generating random graph 882/1000
# Generating random graph 883/1000
# Generating random graph 884/1000
# Generating random graph 885/1000
# Generating random graph 886/1000
# Generating random graph 887/1000
# Generating random graph 888/1000
# Generating random graph 889/1000
# Generating random graph 890/1000
# Generating random graph 891/1000
# Generating random graph 892/1000
# Generating random graph 893/1000
# Generating random graph 894/1000
# Generating random graph 895/1000
# Generating random graph 896/1000
# Generating random graph 897/1000
# Generating random graph 898/1000
# Generating random graph 899/1000
# Generating random graph 900/1000
# Generating random graph 901/1000
# Generating random graph 902/1000
# Generating random graph 903/1000
# Generating random graph 904/1000
# Generating random graph 905/1000
# Generating random graph 906/1000
# Generating random graph 907/1000
# Generating random graph 908/1000
# Generating random graph 909/1000
# Generating random graph 910/1000
# Generating random graph 911/1000
# Generating random graph 912/1000
# Generating random graph 913/1000
# Generating random graph 914/1000
# Generating random graph 915/1000
# Generating random graph 916/1000
# Generating random graph 917/1000
# Generating random graph 918/1000
# Generating random graph 919/1000
# Generating random graph 920/1000
# Generating random graph 921/1000
# Generating random graph 922/1000
# Generating random graph 923/1000
# Generating random graph 924/1000
# Generating random graph 925/1000
# Generating random graph 926/1000
# Generating random graph 927/1000
# Generating random graph 928/1000
# Generating random graph 929/1000
# Generating random graph 930/1000
# Generating random graph 931/1000
# Generating random graph 932/1000
# Generating random graph 933/1000
# Generating random graph 934/1000
# Generating random graph 935/1000
# Generating random graph 936/1000
# Generating random graph 937/1000
# Generating random graph 938/1000
# Generating random graph 939/1000
# Generating random graph 940/1000
# Generating random graph 941/1000
# Generating random graph 942/1000
# Generating random graph 943/1000
# Generating random graph 944/1000
# Generating random graph 945/1000
# Generating random graph 946/1000
# Generating random graph 947/1000
# Generating random graph 948/1000
# Generating random graph 949/1000
# Generating random graph 950/1000
# Generating random graph 951/1000
# Generating random graph 952/1000
# Generating random graph 953/1000
# Generating random graph 954/1000
# Generating random graph 955/1000
# Generating random graph 956/1000
# Generating random graph 957/1000
# Generating random graph 958/1000
# Generating random graph 959/1000
# Generating random graph 960/1000
# Generating random graph 961/1000
# Generating random graph 962/1000
# Generating random graph 963/1000
# Generating random graph 964/1000
# Generating random graph 965/1000
# Generating random graph 966/1000
# Generating random graph 967/1000
# Generating random graph 968/1000
# Generating random graph 969/1000
# Generating random graph 970/1000
# Generating random graph 971/1000
# Generating random graph 972/1000
# Generating random graph 973/1000
# Generating random graph 974/1000
# Generating random graph 975/1000
# Generating random graph 976/1000
# Generating random graph 977/1000
# Generating random graph 978/1000
# Generating random graph 979/1000
# Generating random graph 980/1000
# Generating random graph 981/1000
# Generating random graph 982/1000
# Generating random graph 983/1000
# Generating random graph 984/1000
# Generating random graph 985/1000
# Generating random graph 986/1000
# Generating random graph 987/1000
# Generating random graph 988/1000
# Generating random graph 989/1000
# Generating random graph 990/1000
# Generating random graph 991/1000
# Generating random graph 992/1000
# Generating random graph 993/1000
# Generating random graph 994/1000
# Generating random graph 995/1000
# Generating random graph 996/1000
# Generating random graph 997/1000
# Generating random graph 998/1000
# Generating random graph 999/1000
# Generating random graph 1000/1000
# Started calculating motifs z-scores:
# /tmp/ipykernel_303720/331332085.py:9: RuntimeWarning: divide by zero encountered in double_scalars
#   z_score = (motif_n_target - motif_n_random_networks.mean())/random_sigma
# Started generating 1000 random graphs:
# Generating random graph 1/1000
# Generating random graph 2/1000
# Generating random graph 3/1000
# Generating random graph 4/1000
# Generating random graph 5/1000
# Generating random graph 6/1000
# Generating random graph 7/1000
# Generating random graph 8/1000
# Generating random graph 9/1000
# Generating random graph 10/1000
# Generating random graph 11/1000
# Generating random graph 12/1000
# Generating random graph 13/1000
# Generating random graph 14/1000
# Generating random graph 15/1000
# Generating random graph 16/1000
# Generating random graph 17/1000
# Generating random graph 18/1000
# Generating random graph 19/1000
# Generating random graph 20/1000
# Generating random graph 21/1000
# Generating random graph 22/1000
# Generating random graph 23/1000
# Generating random graph 24/1000
# Generating random graph 25/1000
# Generating random graph 26/1000
# Generating random graph 27/1000
# Generating random graph 28/1000
# Generating random graph 29/1000
# Generating random graph 30/1000
# Generating random graph 31/1000
# Generating random graph 32/1000
# Generating random graph 33/1000
# Generating random graph 34/1000
# Generating random graph 35/1000
# Generating random graph 36/1000
# Generating random graph 37/1000
# Generating random graph 38/1000
# Generating random graph 39/1000
# Generating random graph 40/1000
# Generating random graph 41/1000
# Generating random graph 42/1000
# Generating random graph 43/1000
# Generating random graph 44/1000
# Generating random graph 45/1000
# Generating random graph 46/1000
# Generating random graph 47/1000
# Generating random graph 48/1000
# Generating random graph 49/1000
# Generating random graph 50/1000
# Generating random graph 51/1000
# Generating random graph 52/1000
# Generating random graph 53/1000
# Generating random graph 54/1000
# Generating random graph 55/1000
# Generating random graph 56/1000
# Generating random graph 57/1000
# Generating random graph 58/1000
# Generating random graph 59/1000
# Generating random graph 60/1000
# Generating random graph 61/1000
# Generating random graph 62/1000
# Generating random graph 63/1000
# Generating random graph 64/1000
# Generating random graph 65/1000
# Generating random graph 66/1000
# Generating random graph 67/1000
# Generating random graph 68/1000
# Generating random graph 69/1000
# Generating random graph 70/1000
# Generating random graph 71/1000
# Generating random graph 72/1000
# Generating random graph 73/1000
# Generating random graph 74/1000
# Generating random graph 75/1000
# Generating random graph 76/1000
# Generating random graph 77/1000
# Generating random graph 78/1000
# Generating random graph 79/1000
# Generating random graph 80/1000
# Generating random graph 81/1000
# Generating random graph 82/1000
# Generating random graph 83/1000
# Generating random graph 84/1000
# Generating random graph 85/1000
# Generating random graph 86/1000
# Generating random graph 87/1000
# Generating random graph 88/1000
# Generating random graph 89/1000
# Generating random graph 90/1000
# Generating random graph 91/1000
# Generating random graph 92/1000
# Generating random graph 93/1000
# Generating random graph 94/1000
# Generating random graph 95/1000
# Generating random graph 96/1000
# Generating random graph 97/1000
# Generating random graph 98/1000
# Generating random graph 99/1000
# Generating random graph 100/1000
# Generating random graph 101/1000
# Generating random graph 102/1000
# Generating random graph 103/1000
# Generating random graph 104/1000
# Generating random graph 105/1000
# Generating random graph 106/1000
# Generating random graph 107/1000
# Generating random graph 108/1000
# Generating random graph 109/1000
# Generating random graph 110/1000
# Generating random graph 111/1000
# Generating random graph 112/1000
# Generating random graph 113/1000
# Generating random graph 114/1000
# Generating random graph 115/1000
# Generating random graph 116/1000
# Generating random graph 117/1000
# Generating random graph 118/1000
# Generating random graph 119/1000
# Generating random graph 120/1000
# Generating random graph 121/1000
# Generating random graph 122/1000
# Generating random graph 123/1000
# Generating random graph 124/1000
# Generating random graph 125/1000
# Generating random graph 126/1000
# Generating random graph 127/1000
# Generating random graph 128/1000
# Generating random graph 129/1000
# Generating random graph 130/1000
# Generating random graph 131/1000
# Generating random graph 132/1000
# Generating random graph 133/1000
# Generating random graph 134/1000
# Generating random graph 135/1000
# Generating random graph 136/1000
# Generating random graph 137/1000
# Generating random graph 138/1000
# Generating random graph 139/1000
# Generating random graph 140/1000
# Generating random graph 141/1000
# Generating random graph 142/1000
# Generating random graph 143/1000
# Generating random graph 144/1000
# Generating random graph 145/1000
# Generating random graph 146/1000
# Generating random graph 147/1000
# Generating random graph 148/1000
# Generating random graph 149/1000
# Generating random graph 150/1000
# Generating random graph 151/1000
# Generating random graph 152/1000
# Generating random graph 153/1000
# Generating random graph 154/1000
# Generating random graph 155/1000
# Generating random graph 156/1000
# Generating random graph 157/1000
# Generating random graph 158/1000
# Generating random graph 159/1000
# Generating random graph 160/1000
# Generating random graph 161/1000
# Generating random graph 162/1000
# Generating random graph 163/1000
# Generating random graph 164/1000
# Generating random graph 165/1000
# Generating random graph 166/1000
# Generating random graph 167/1000
# Generating random graph 168/1000
# Generating random graph 169/1000
# Generating random graph 170/1000
# Generating random graph 171/1000
# Generating random graph 172/1000
# Generating random graph 173/1000
# Generating random graph 174/1000
# Generating random graph 175/1000
# Generating random graph 176/1000
# Generating random graph 177/1000
# Generating random graph 178/1000
# Generating random graph 179/1000
# Generating random graph 180/1000
# Generating random graph 181/1000
# Generating random graph 182/1000
# Generating random graph 183/1000
# Generating random graph 184/1000
# Generating random graph 185/1000
# Generating random graph 186/1000
# Generating random graph 187/1000
# Generating random graph 188/1000
# Generating random graph 189/1000
# Generating random graph 190/1000
# Generating random graph 191/1000
# Generating random graph 192/1000
# Generating random graph 193/1000
# Generating random graph 194/1000
# Generating random graph 195/1000
# Generating random graph 196/1000
# Generating random graph 197/1000
# Generating random graph 198/1000
# Generating random graph 199/1000
# Generating random graph 200/1000
# Generating random graph 201/1000
# Generating random graph 202/1000
# Generating random graph 203/1000
# Generating random graph 204/1000
# Generating random graph 205/1000
# Generating random graph 206/1000
# Generating random graph 207/1000
# Generating random graph 208/1000
# Generating random graph 209/1000
# Generating random graph 210/1000
# Generating random graph 211/1000
# Generating random graph 212/1000
# Generating random graph 213/1000
# Generating random graph 214/1000
# Generating random graph 215/1000
# Generating random graph 216/1000
# Generating random graph 217/1000
# Generating random graph 218/1000
# Generating random graph 219/1000
# Generating random graph 220/1000
# Generating random graph 221/1000
# Generating random graph 222/1000
# Generating random graph 223/1000
# Generating random graph 224/1000
# Generating random graph 225/1000
# Generating random graph 226/1000
# Generating random graph 227/1000
# Generating random graph 228/1000
# Generating random graph 229/1000
# Generating random graph 230/1000
# Generating random graph 231/1000
# Generating random graph 232/1000
# Generating random graph 233/1000
# Generating random graph 234/1000
# Generating random graph 235/1000
# Generating random graph 236/1000
# Generating random graph 237/1000
# Generating random graph 238/1000
# Generating random graph 239/1000
# Generating random graph 240/1000
# Generating random graph 241/1000
# Generating random graph 242/1000
# Generating random graph 243/1000
# Generating random graph 244/1000
# Generating random graph 245/1000
# Generating random graph 246/1000
# Generating random graph 247/1000
# Generating random graph 248/1000
# Generating random graph 249/1000
# Generating random graph 250/1000
# Generating random graph 251/1000
# Generating random graph 252/1000
# Generating random graph 253/1000
# Generating random graph 254/1000
# Generating random graph 255/1000
# Generating random graph 256/1000
# Generating random graph 257/1000
# Generating random graph 258/1000
# Generating random graph 259/1000
# Generating random graph 260/1000
# Generating random graph 261/1000
# Generating random graph 262/1000
# Generating random graph 263/1000
# Generating random graph 264/1000
# Generating random graph 265/1000
# Generating random graph 266/1000
# Generating random graph 267/1000
# Generating random graph 268/1000
# Generating random graph 269/1000
# Generating random graph 270/1000
# Generating random graph 271/1000
# Generating random graph 272/1000
# Generating random graph 273/1000
# Generating random graph 274/1000
# Generating random graph 275/1000
# Generating random graph 276/1000
# Generating random graph 277/1000
# Generating random graph 278/1000
# Generating random graph 279/1000
# Generating random graph 280/1000
# Generating random graph 281/1000
# Generating random graph 282/1000
# Generating random graph 283/1000
# Generating random graph 284/1000
# Generating random graph 285/1000
# Generating random graph 286/1000
# Generating random graph 287/1000
# Generating random graph 288/1000
# Generating random graph 289/1000
# Generating random graph 290/1000
# Generating random graph 291/1000
# Generating random graph 292/1000
# Generating random graph 293/1000
# Generating random graph 294/1000
# Generating random graph 295/1000
# Generating random graph 296/1000
# Generating random graph 297/1000
# Generating random graph 298/1000
# Generating random graph 299/1000
# Generating random graph 300/1000
# Generating random graph 301/1000
# Generating random graph 302/1000
# Generating random graph 303/1000
# Generating random graph 304/1000
# Generating random graph 305/1000
# Generating random graph 306/1000
# Generating random graph 307/1000
# Generating random graph 308/1000
# Generating random graph 309/1000
# Generating random graph 310/1000
# Generating random graph 311/1000
# Generating random graph 312/1000
# Generating random graph 313/1000
# Generating random graph 314/1000
# Generating random graph 315/1000
# Generating random graph 316/1000
# Generating random graph 317/1000
# Generating random graph 318/1000
# Generating random graph 319/1000
# Generating random graph 320/1000
# Generating random graph 321/1000
# Generating random graph 322/1000
# Generating random graph 323/1000
# Generating random graph 324/1000
# Generating random graph 325/1000
# Generating random graph 326/1000
# Generating random graph 327/1000
# Generating random graph 328/1000
# Generating random graph 329/1000
# Generating random graph 330/1000
# Generating random graph 331/1000
# Generating random graph 332/1000
# Generating random graph 333/1000
# Generating random graph 334/1000
# Generating random graph 335/1000
# Generating random graph 336/1000
# Generating random graph 337/1000
# Generating random graph 338/1000
# Generating random graph 339/1000
# Generating random graph 340/1000
# Generating random graph 341/1000
# Generating random graph 342/1000
# Generating random graph 343/1000
# Generating random graph 344/1000
# Generating random graph 345/1000
# Generating random graph 346/1000
# Generating random graph 347/1000
# Generating random graph 348/1000
# Generating random graph 349/1000
# Generating random graph 350/1000
# Generating random graph 351/1000
# Generating random graph 352/1000
# Generating random graph 353/1000
# Generating random graph 354/1000
# Generating random graph 355/1000
# Generating random graph 356/1000
# Generating random graph 357/1000
# Generating random graph 358/1000
# Generating random graph 359/1000
# Generating random graph 360/1000
# Generating random graph 361/1000
# Generating random graph 362/1000
# Generating random graph 363/1000
# Generating random graph 364/1000
# Generating random graph 365/1000
# Generating random graph 366/1000
# Generating random graph 367/1000
# Generating random graph 368/1000
# Generating random graph 369/1000
# Generating random graph 370/1000
# Generating random graph 371/1000
# Generating random graph 372/1000
# Generating random graph 373/1000
# Generating random graph 374/1000
# Generating random graph 375/1000
# Generating random graph 376/1000
# Generating random graph 377/1000
# Generating random graph 378/1000
# Generating random graph 379/1000
# Generating random graph 380/1000
# Generating random graph 381/1000
# Generating random graph 382/1000
# Generating random graph 383/1000
# Generating random graph 384/1000
# Generating random graph 385/1000
# Generating random graph 386/1000
# Generating random graph 387/1000
# Generating random graph 388/1000
# Generating random graph 389/1000
# Generating random graph 390/1000
# Generating random graph 391/1000
# Generating random graph 392/1000
# Generating random graph 393/1000
# Generating random graph 394/1000
# Generating random graph 395/1000
# Generating random graph 396/1000
# Generating random graph 397/1000
# Generating random graph 398/1000
# Generating random graph 399/1000
# Generating random graph 400/1000
# Generating random graph 401/1000
# Generating random graph 402/1000
# Generating random graph 403/1000
# Generating random graph 404/1000
# Generating random graph 405/1000
# Generating random graph 406/1000
# Generating random graph 407/1000
# Generating random graph 408/1000
# Generating random graph 409/1000
# Generating random graph 410/1000
# Generating random graph 411/1000
# Generating random graph 412/1000
# Generating random graph 413/1000
# Generating random graph 414/1000
# Generating random graph 415/1000
# Generating random graph 416/1000
# Generating random graph 417/1000
# Generating random graph 418/1000
# Generating random graph 419/1000
# Generating random graph 420/1000
# Generating random graph 421/1000
# Generating random graph 422/1000
# Generating random graph 423/1000
# Generating random graph 424/1000
# Generating random graph 425/1000
# Generating random graph 426/1000
# Generating random graph 427/1000
# Generating random graph 428/1000
# Generating random graph 429/1000
# Generating random graph 430/1000
# Generating random graph 431/1000
# Generating random graph 432/1000
# Generating random graph 433/1000
# Generating random graph 434/1000
# Generating random graph 435/1000
# Generating random graph 436/1000
# Generating random graph 437/1000
# Generating random graph 438/1000
# Generating random graph 439/1000
# Generating random graph 440/1000
# Generating random graph 441/1000
# Generating random graph 442/1000
# Generating random graph 443/1000
# Generating random graph 444/1000
# Generating random graph 445/1000
# Generating random graph 446/1000
# Generating random graph 447/1000
# Generating random graph 448/1000
# Generating random graph 449/1000
# Generating random graph 450/1000
# Generating random graph 451/1000
# Generating random graph 452/1000
# ...
# Generating random graph 518/1000
# Generating random graph 519/1000
# Generating random graph 520/1000
# Generating random graph 521/1000
# Generating random graph 522/1000
# Generating random graph 523/1000
# Generating random graph 524/1000
# Generating random graph 525/1000
# Generating random graph 526/1000
# Generating random graph 527/1000
# Generating random graph 528/1000
# Generating random graph 529/1000
# Generating random graph 530/1000
# Generating random graph 531/1000
# Generating random graph 532/1000
# Generating random graph 533/1000
# Generating random graph 534/1000
# Generating random graph 535/1000
# Generating random graph 536/1000
# Generating random graph 537/1000
# Generating random graph 538/1000
# Generating random graph 539/1000
# Generating random graph 540/1000
# Generating random graph 541/1000
# Generating random graph 542/1000
# Generating random graph 543/1000
# Generating random graph 544/1000
# Generating random graph 545/1000
# Generating random graph 546/1000
# Generating random graph 547/1000
# Generating random graph 548/1000
# Generating random graph 549/1000
# Generating random graph 550/1000
# Generating random graph 551/1000
# Generating random graph 552/1000
# Generating random graph 553/1000
# Generating random graph 554/1000
# Generating random graph 555/1000
# Generating random graph 556/1000
# Generating random graph 557/1000
# Generating random graph 558/1000
# Generating random graph 559/1000
# Generating random graph 560/1000
# Generating random graph 561/1000
# Generating random graph 562/1000
# Generating random graph 563/1000
# Generating random graph 564/1000
# Generating random graph 565/1000
# Generating random graph 566/1000
# Generating random graph 567/1000
# Generating random graph 568/1000
# Generating random graph 569/1000
# Generating random graph 570/1000
# Generating random graph 571/1000
# Generating random graph 572/1000
# Generating random graph 573/1000
# Generating random graph 574/1000
# Generating random graph 575/1000
# Generating random graph 576/1000
# Generating random graph 577/1000
# Generating random graph 578/1000
# Generating random graph 579/1000
# Generating random graph 580/1000
# Generating random graph 581/1000
# Generating random graph 582/1000
# Generating random graph 583/1000
# Generating random graph 584/1000
# Generating random graph 585/1000
# Generating random graph 586/1000
# Generating random graph 587/1000
# Generating random graph 588/1000
# Generating random graph 589/1000
# Generating random graph 590/1000
# Generating random graph 591/1000
# Generating random graph 592/1000
# Generating random graph 593/1000
# Generating random graph 594/1000
# Generating random graph 595/1000
# Generating random graph 596/1000
# Generating random graph 597/1000
# Generating random graph 598/1000
# Generating random graph 599/1000
# Generating random graph 600/1000
# Generating random graph 601/1000
# Generating random graph 602/1000
# Generating random graph 603/1000
# Generating random graph 604/1000
# Generating random graph 605/1000
# Generating random graph 606/1000
# Generating random graph 607/1000
# Generating random graph 608/1000
# Generating random graph 609/1000
# Generating random graph 610/1000
# Generating random graph 611/1000
# Generating random graph 612/1000
# Generating random graph 613/1000
# Generating random graph 614/1000
# Generating random graph 615/1000
# Generating random graph 616/1000
# Generating random graph 617/1000
# Generating random graph 618/1000
# Generating random graph 619/1000
# Generating random graph 620/1000
# Generating random graph 621/1000
# Generating random graph 622/1000
# Generating random graph 623/1000
# Generating random graph 624/1000
# Generating random graph 625/1000
# Generating random graph 626/1000
# Generating random graph 627/1000
# Generating random graph 628/1000
# Generating random graph 629/1000
# Generating random graph 630/1000
# Generating random graph 631/1000
# Generating random graph 632/1000
# Generating random graph 633/1000
# Generating random graph 634/1000
# Generating random graph 635/1000
# Generating random graph 636/1000
# Generating random graph 637/1000
# Generating random graph 638/1000
# Generating random graph 639/1000
# Generating random graph 640/1000
# Generating random graph 641/1000
# Generating random graph 642/1000
# Generating random graph 643/1000
# Generating random graph 644/1000
# Generating random graph 645/1000
# Generating random graph 646/1000
# Generating random graph 647/1000
# Generating random graph 648/1000
# Generating random graph 649/1000
# Generating random graph 650/1000
# Generating random graph 651/1000
# Generating random graph 652/1000
# Generating random graph 653/1000
# Generating random graph 654/1000
# Generating random graph 655/1000
# Generating random graph 656/1000
# Generating random graph 657/1000
# Generating random graph 658/1000
# Generating random graph 659/1000
# Generating random graph 660/1000
# Generating random graph 661/1000
# Generating random graph 662/1000
# Generating random graph 663/1000
# Generating random graph 664/1000
# Generating random graph 665/1000
# Generating random graph 666/1000
# Generating random graph 667/1000
# Generating random graph 668/1000
# Generating random graph 669/1000
# Generating random graph 670/1000
# Generating random graph 671/1000
# Generating random graph 672/1000
# Generating random graph 673/1000
# Generating random graph 674/1000
# Generating random graph 675/1000
# Generating random graph 676/1000
# Generating random graph 677/1000
# Generating random graph 678/1000
# Generating random graph 679/1000
# Generating random graph 680/1000
# Generating random graph 681/1000
# Generating random graph 682/1000
# Generating random graph 683/1000
# Generating random graph 684/1000
# Generating random graph 685/1000
# Generating random graph 686/1000
# Generating random graph 687/1000
# Generating random graph 688/1000
# Generating random graph 689/1000
# Generating random graph 690/1000
# Generating random graph 691/1000
# Generating random graph 692/1000
# Generating random graph 693/1000
# Generating random graph 694/1000
# Generating random graph 695/1000
# Generating random graph 696/1000
# Generating random graph 697/1000
# Generating random graph 698/1000
# Generating random graph 699/1000
# Generating random graph 700/1000
# Generating random graph 701/1000
# Generating random graph 702/1000
# Generating random graph 703/1000
# Generating random graph 704/1000
# Generating random graph 705/1000
# Generating random graph 706/1000
# Generating random graph 707/1000
# Generating random graph 708/1000
# Generating random graph 709/1000
# Generating random graph 710/1000
# Generating random graph 711/1000
# Generating random graph 712/1000
# Generating random graph 713/1000
# Generating random graph 714/1000
# Generating random graph 715/1000
# Generating random graph 716/1000
# Generating random graph 717/1000
# Generating random graph 718/1000
# Generating random graph 719/1000
# Generating random graph 720/1000
# Generating random graph 721/1000
# Generating random graph 722/1000
# Generating random graph 723/1000
# Generating random graph 724/1000
# Generating random graph 725/1000
# Generating random graph 726/1000
# Generating random graph 727/1000
# Generating random graph 728/1000
# Generating random graph 729/1000
# Generating random graph 730/1000
# Generating random graph 731/1000
# Generating random graph 732/1000
# Generating random graph 733/1000
# Generating random graph 734/1000
# Generating random graph 735/1000
# Generating random graph 736/1000
# Generating random graph 737/1000
# Generating random graph 738/1000
# Generating random graph 739/1000
# Generating random graph 740/1000
# Generating random graph 741/1000
# Generating random graph 742/1000
# Generating random graph 743/1000
# Generating random graph 744/1000
# Generating random graph 745/1000
# Generating random graph 746/1000
# Generating random graph 747/1000
# Generating random graph 748/1000
# Generating random graph 749/1000
# Generating random graph 750/1000
# Generating random graph 751/1000
# Generating random graph 752/1000
# Generating random graph 753/1000
# Generating random graph 754/1000
# Generating random graph 755/1000
# Generating random graph 756/1000
# Generating random graph 757/1000
# Generating random graph 758/1000
# Generating random graph 759/1000
# Generating random graph 760/1000
# Generating random graph 761/1000
# Generating random graph 762/1000
# Generating random graph 763/1000
# Generating random graph 764/1000
# Generating random graph 765/1000
# Generating random graph 766/1000
# Generating random graph 767/1000
# Generating random graph 768/1000
# Generating random graph 769/1000
# Generating random graph 770/1000
# Generating random graph 771/1000
# Generating random graph 772/1000
# Generating random graph 773/1000
# Generating random graph 774/1000
# Generating random graph 775/1000
# Generating random graph 776/1000
# Generating random graph 777/1000
# Generating random graph 778/1000
# Generating random graph 779/1000
# Generating random graph 780/1000
# Generating random graph 781/1000
# Generating random graph 782/1000
# Generating random graph 783/1000
# Generating random graph 784/1000
# Generating random graph 785/1000
# Generating random graph 786/1000
# Generating random graph 787/1000
# Generating random graph 788/1000
# Generating random graph 789/1000
# Generating random graph 790/1000
# Generating random graph 791/1000
# Generating random graph 792/1000
# Generating random graph 793/1000
# Generating random graph 794/1000
# Generating random graph 795/1000
# Generating random graph 796/1000
# Generating random graph 797/1000
# Generating random graph 798/1000
# Generating random graph 799/1000
# Generating random graph 800/1000
# Generating random graph 801/1000
# Generating random graph 802/1000
# Generating random graph 803/1000
# Generating random graph 804/1000
# Generating random graph 805/1000
# Generating random graph 806/1000
# Generating random graph 807/1000
# Generating random graph 808/1000
# Generating random graph 809/1000
# Generating random graph 810/1000
# Generating random graph 811/1000
# Generating random graph 812/1000
# Generating random graph 813/1000
# Generating random graph 814/1000
# Generating random graph 815/1000
# Generating random graph 816/1000
# Generating random graph 817/1000
# Generating random graph 818/1000
# Generating random graph 819/1000
# Generating random graph 820/1000
# Generating random graph 821/1000
# Generating random graph 822/1000
# Generating random graph 823/1000
# Generating random graph 824/1000
# Generating random graph 825/1000
# Generating random graph 826/1000
# Generating random graph 827/1000
# Generating random graph 828/1000
# Generating random graph 829/1000
# Generating random graph 830/1000
# Generating random graph 831/1000
# Generating random graph 832/1000
# Generating random graph 833/1000
# Generating random graph 834/1000
# Generating random graph 835/1000
# Generating random graph 836/1000
# Generating random graph 837/1000
# Generating random graph 838/1000
# Generating random graph 839/1000
# Generating random graph 840/1000
# Generating random graph 841/1000
# Generating random graph 842/1000
# Generating random graph 843/1000
# Generating random graph 844/1000
# Generating random graph 845/1000
# Generating random graph 846/1000
# Generating random graph 847/1000
# Generating random graph 848/1000
# Generating random graph 849/1000
# Generating random graph 850/1000
# Generating random graph 851/1000
# Generating random graph 852/1000
# Generating random graph 853/1000
# Generating random graph 854/1000
# Generating random graph 855/1000
# Generating random graph 856/1000
# Generating random graph 857/1000
# Generating random graph 858/1000
# Generating random graph 859/1000
# Generating random graph 860/1000
# Generating random graph 861/1000
# Generating random graph 862/1000
# Generating random graph 863/1000
# Generating random graph 864/1000
# Generating random graph 865/1000
# Generating random graph 866/1000
# Generating random graph 867/1000
# Generating random graph 868/1000
# Generating random graph 869/1000
# Generating random graph 870/1000
# Generating random graph 871/1000
# Generating random graph 872/1000
# Generating random graph 873/1000
# Generating random graph 874/1000
# Generating random graph 875/1000
# Generating random graph 876/1000
# Generating random graph 877/1000
# Generating random graph 878/1000
# Generating random graph 879/1000
# Generating random graph 880/1000
# Generating random graph 881/1000
# Generating random graph 882/1000
# Generating random graph 883/1000
# Generating random graph 884/1000
# Generating random graph 885/1000
# Generating random graph 886/1000
# Generating random graph 887/1000
# Generating random graph 888/1000
# Generating random graph 889/1000
# Generating random graph 890/1000
# Generating random graph 891/1000
# Generating random graph 892/1000
# Generating random graph 893/1000
# Generating random graph 894/1000
# Generating random graph 895/1000
# Generating random graph 896/1000
# Generating random graph 897/1000
# Generating random graph 898/1000
# Generating random graph 899/1000
# Generating random graph 900/1000
# Generating random graph 901/1000
# Generating random graph 902/1000
# Generating random graph 903/1000
# Generating random graph 904/1000
# Generating random graph 905/1000
# Generating random graph 906/1000
# Generating random graph 907/1000
# Generating random graph 908/1000
# Generating random graph 909/1000
# Generating random graph 910/1000
# Generating random graph 911/1000
# Generating random graph 912/1000
# Generating random graph 913/1000
# Generating random graph 914/1000
# Generating random graph 915/1000
# Generating random graph 916/1000
# Generating random graph 917/1000
# Generating random graph 918/1000
# Generating random graph 919/1000
# Generating random graph 920/1000
# Generating random graph 921/1000
# Generating random graph 922/1000
# Generating random graph 923/1000
# Generating random graph 924/1000
# Generating random graph 925/1000
# Generating random graph 926/1000
# Generating random graph 927/1000
# Generating random graph 928/1000
# Generating random graph 929/1000
# Generating random graph 930/1000
# Generating random graph 931/1000
# Generating random graph 932/1000
# Generating random graph 933/1000
# Generating random graph 934/1000
# Generating random graph 935/1000
# Generating random graph 936/1000
# Generating random graph 937/1000
# Generating random graph 938/1000
# Generating random graph 939/1000
# Generating random graph 940/1000
# Generating random graph 941/1000
# Generating random graph 942/1000
# Generating random graph 943/1000
# Generating random graph 944/1000
# Generating random graph 945/1000
# Generating random graph 946/1000
# Generating random graph 947/1000
# Generating random graph 948/1000
# Generating random graph 949/1000
# Generating random graph 950/1000
# Generating random graph 951/1000
# Generating random graph 952/1000
# Generating random graph 953/1000
# Generating random graph 954/1000
# Generating random graph 955/1000
# Generating random graph 956/1000
# Generating random graph 957/1000
# Generating random graph 958/1000
# Generating random graph 959/1000
# Generating random graph 960/1000
# Generating random graph 961/1000
# Generating random graph 962/1000
# Generating random graph 963/1000
# Generating random graph 964/1000
# Generating random graph 965/1000
# Generating random graph 966/1000
# Generating random graph 967/1000
# Generating random graph 968/1000
# Generating random graph 969/1000
# Generating random graph 970/1000
# Generating random graph 971/1000
# Generating random graph 972/1000
# Generating random graph 973/1000
# Generating random graph 974/1000
# Generating random graph 975/1000
# Generating random graph 976/1000
# Generating random graph 977/1000
# Generating random graph 978/1000
# Generating random graph 979/1000
# Generating random graph 980/1000
# Generating random graph 981/1000
# Generating random graph 982/1000
# Generating random graph 983/1000
# Generating random graph 984/1000
# Generating random graph 985/1000
# Generating random graph 986/1000
# Generating random graph 987/1000
# Generating random graph 988/1000
# Generating random graph 989/1000
# Generating random graph 990/1000
# Generating random graph 991/1000
# Generating random graph 992/1000
# Generating random graph 993/1000
# Generating random graph 994/1000
# Generating random graph 995/1000
# Generating random graph 996/1000
# Generating random graph 997/1000
# Generating random graph 998/1000
# Generating random graph 999/1000
# Generating random graph 1000/1000
# Started calculating motifs z-scores:

# %%
subgraph_motifs_zscores
# Out:
# {'subgraph_area_fasciculus retroflexus.gt': {'motifs_zscores': {<Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08722bb50>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ce44ee0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0875954b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087595810>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087594a90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0875944c0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08764cc70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871cc730>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08764c0d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08cddd1e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08cddc520>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08cddc5e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08cddca00>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ce155d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ce17c10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce15ae0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce16dd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08712ba60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c992b60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c139120>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca0ab60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca08f70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca0a860>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087514700>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087515810>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087514820>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2ec310>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c287490>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2ee4d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2edb10>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c84d7e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c84c6d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0875967d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087594850>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087595cf0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087594a30>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2617e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2606d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2607c0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c59e080>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c59c280>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c59c100>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca0a530>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c64bd60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca08c70>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca09660>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6f40d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6a3d00>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c6f6710>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c6f45e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087737ca0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087737b80>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c16bee0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6e9450>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6ebf10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c6e95d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3cd7b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3cc6d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c3cc7c0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4af2e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4ae3e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4ae740>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08725c700>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08725c610>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087259660>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08725a920>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087259870>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087259f00>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c84cb80>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c84d330>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c635ea0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c637fd0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c635780>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871b1150>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871b0490>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0871b0550>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087760a90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087760d60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087760c40>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4b4640>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4b4550>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08747fd00>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08747e560>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9d1780>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9d06a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c9d0790>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c579f90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c556800>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c5786d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c578550>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0878554e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087854310>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0878549d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087854400>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4ac190>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c243400>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087515e10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087516ec0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7cd3c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7cc490>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2636a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c262380>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c262860>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087530430>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c84c130>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c84e830>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c84e3b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1f1810>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1f0700>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1f0dc0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1f0820>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c455330>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c454670>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c5395a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c538490>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c5385b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871cc0a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087800700>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca4ce20>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca4d3f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca4d6f0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca4e9b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087326dd0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1c18a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08cdc0880>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08cdc0610>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087724e80>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0877257b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087726590>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087725ab0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9d31c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9d30a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c9d1f90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c070280>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c070880>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c070c70>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4ed810>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4ec730>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4ec820>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874bb1c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874b9a50>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0874b9fc0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0874bafb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08719d1e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08719c520>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08719c5e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c72ea40>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c72f400>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c72e680>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7cd270>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7cf2e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c7cf5e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7863b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c786410>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c785f90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087485180>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874844c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087484580>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca08550>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca09ed0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca08700>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872c47f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872c6560>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0872c6860>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1b5000>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1b7b20>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1b7e20>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1b4640>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4ece20>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4ed300>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4ed600>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4ee8c0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4b5780>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4b41c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4b5090>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08728d7b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08728c6d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08728c820>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08728cdf0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087732140>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087730f10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087731210>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874646a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087465780>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087464790>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7a7910>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7a5570>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c7a4580>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ce4cac0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ce4ca60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce4cdc0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d0cfa90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d0ccc70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08d0cfd90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c38ed70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c38c940>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c38f070>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9b14b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9b0190>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c9b0850>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c9b0400>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c334760>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c336230>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c336530>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c3378b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1699c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c16b2b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c16beb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4e50c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4e4400>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4e44c0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c340730>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c342f50>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c3419f0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c186dd0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c187bb0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c186f80>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c44c3d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c44d600>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c44d900>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2f1780>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2f06a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2f0790>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2f0dc0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872e7760>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08744a740>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087183ee0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ce0d7e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ce0c6d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce0cd90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce0c7c0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c581300>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08744a980>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca0b460>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca09720>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca0bd60>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca0bc10>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08792e620>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08792c0d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087164dc0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087166080>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0871643d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087164040>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3edb40>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871e19c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c3ed180>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3f49d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3f54b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c3f57b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1da200>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1da590>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1da1a0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1d88b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087450dc0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087450310>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0874505b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087450a30>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c242cb0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087575db0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2411b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872fdb70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9c4df0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0872fc250>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0872fecb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c208550>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c209630>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c209930>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874c5510>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874c42e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0874c46d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4cb9d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4c9750>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6579d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6540d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c52c460>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c52c520>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c52cca0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087170160>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871711b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0871714b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871d6b00>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871d73a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0871d5db0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0871d5bd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c557df0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c555c00>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c556ad0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1e9720>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1eb700>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1e9510>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1eb400>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872e4bb0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872e5c60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871cc2b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871ceda0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0871ce9e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c44c580>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c44ff40>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c44dc90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7dd3f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7de440>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c7de740>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3adf30>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3ad7e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c3aeec0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c3adbd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2b2950>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2b3370>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9d0370>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9d20e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c786e00>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c785360>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c787cd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08cd6c160>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08771a530>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08cd6dcc0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08cd6dbd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c99ee30>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c99cd60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c99c2e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c99f130>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c42c0d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c42d3f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2981c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2999f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c299cf0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c539e10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c5383d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c5398a0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c53ac20>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6832b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c682920>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c681210>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874726e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874715d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0876253f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087625f90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087625900>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087595fc0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0875948e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087597a30>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6c1450>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6c3a90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08719da50>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1c0850>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1c2620>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9f0b20>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9f0430>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c9f1180>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3c4850>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3c65f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c64cb20>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c64dff0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c64cf10>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c64e620>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c84ea10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c84d1b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c84cee0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c84c0d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872c76a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872c5810>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0872c51e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca2a410>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca2b8e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca2be50>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087091930>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087742aa0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087740310>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087741900>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c97dc00>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c97d300>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c97e440>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087141f90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0870523e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087140340>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c11b4f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c11ac80>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c11bca0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1e0a90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1e0a30>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08750cbb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08750c520>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087912830>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087911060>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087911d80>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087911f90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c263310>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c260ca0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c263c40>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c374c10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3757e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c375bd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1401f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1409a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca0a5c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ca0abf0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca0b220>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ca0b070>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c16a200>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c169a50>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087936a40>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087936ef0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087935a20>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0879357b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6191b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c6193f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087742080>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0877423b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087742320>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ec42b90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ec40730>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ec41e70>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087442410>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087441c00>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0870530d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0874423b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c5507c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c552320>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c550e20>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c600cd0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c601000>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c602380>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087090790>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08725d780>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08725e500>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08725fe80>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08cdaa080>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c600430>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08cda9f30>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08cda8eb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087925090>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871a9de0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087925120>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c16a8f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1686a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c656050>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c6567d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c335ed0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c334040>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c99d990>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c99d120>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c99e020>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c99e290>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c5e99f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c61d990>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c5e8fa0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c5ea6b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1eb550>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1ebaf0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c1e8eb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2435e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2419c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087574370>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0875752d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087574ee0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087574eb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9d8640>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c307670>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c9d83a0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c9d8730>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0875503a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087551210>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c5256c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c527490>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c526500>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7feaa0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7ff670>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c7ff700>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c784d00>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c786290>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c785bd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c784190>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08708cac0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08708d780>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08708ecb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08708dcc0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2e9510>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2ebd60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2ebaf0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871c29b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871c3880>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc09fd5ba90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087059630>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce011b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4e6bf0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c700cd0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c703a90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c703b80>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872e5b70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872e43a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0872e4730>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c240460>: (-inf,
#     False),
# ...
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087059360>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872e6b60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0872e5b10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce57a30>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce56800>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0873d2800>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0873d0d90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0873d2b90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0873d2530>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086be69e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086be5090>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086be5cc0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086be4100>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08738dae0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9d0c70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08738f7f0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08738e650>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c52aa70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c528f10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d108a30>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d10a800>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08d10b340>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3c4fd0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871d8af0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08783a590>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0871da530>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087183220>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871828c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0871804f0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2b2620>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2b0af0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2b3910>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086c403d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086c421a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087472560>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087752ec0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087470fd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087473bb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7febf0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7fe500>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c7fe530>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086e0ad10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086e0b970>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c64d6f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c64c2e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c64ffd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086d95a80>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086d94760>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086d95030>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08731e5f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086c6cfd0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086c6dd20>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087944190>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087944c70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0879476d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7cfbb0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7ccca0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c7ce230>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c7cc1f0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0874868c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087487b20>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0874857e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086a6a2c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086a6bdf0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086a6b4f0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086a69270>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0878388b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087838c70>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08d1aa2f0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086ecf4c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086ecc3a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c85b730>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c8589d0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4d56c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4d6b90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4d53f0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c4d5510>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087465150>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871b27d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c204310>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c204820>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c205c00>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c2060e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086c01fc0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086c00be0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086c02440>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d148250>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08cd85720>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087280910>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087281720>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086d967a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086d94a60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086d95750>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086be5240>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086be6260>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086be4cd0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086be5780>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086dd00a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086dd19f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086dd0b20>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086dd1cf0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c583280>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08733ee30>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087626ef0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087627df0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3664a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c365090>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9de710>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c9dc730>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c9dc2b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c556080>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087486fe0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086ebb3d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086eb9ba0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086eba590>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d1ab340>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d1aad10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08d1aa530>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08d1ab490>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0873de260>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0873dff10>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0873dfd00>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c374850>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08ce15f30>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce14b80>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08ce154b0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c5a9330>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087835540>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087835330>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4b73a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c4b5930>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0873fe2c0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08d148a90>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7ddcc0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c7df1f0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0871a96c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3594e0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc086f260e0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c34f7c0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2a7880>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c34c550>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1f0100>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c1f1300>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d10ba90>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08d10ad40>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08d10b670>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08d10aa10>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08744a560>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc087448970>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc087449060>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3c6170>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c3c7d00>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08c3c7bb0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08762f3a0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08762fe80>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08762fa00>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc08762cfa0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08708c6d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0875039d0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc0873b5c60>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc08c2c38b0>: (-inf,
#     False),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0873b68c0>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 4 edges, at 0x7fc0873b5000>: (inf,
#     True),
#    <Graph object, undirected, with 4 vertices and 3 edges, at 0x7fc086cacdf0>: (-inf,
#     False),
#    ...}}}

# %% [markdown]
# ### plot motifs distributions with motifs graph draw

# %%
precalc_pickled_distributions_dir_path = f'/scratch/motifsDistributions/MotifDistributionsPerAnnotationPickled/MotifSize_{motifs_len}'
subgraphs_dir = '/scratch/mice_subgraphs/subgraphsByAnnotationLabels'
path_to_save_plots_dir = f'/home/yishaiaz/SubgraphsMotifsResults/MiceSubgraphsResults/MotifsDistributionsByAnnotation/MotifSize_{motifs_len}'
if not os.path.isdir(path_to_save_plots_dir):
    os.makedirs(path_to_save_plots_dir, exist_ok=True)

subgraphs_names = os.listdir(subgraphs_dir)

for subgraph_name in subgraphs_names[:]:
    print(subgraph_name)    
    subgraph_path = os.path.join(subgraphs_dir, subgraph_name)
    subgraph_gt = load_graph(subgraph_path)
    if subgraph_gt.num_vertices() > graph_size_lim:
        continue
    
    motifs_precalculated_dict_pickle_path = os.path.join(precalc_pickled_distributions_dir_path, subgraph_name)
    if not os.path.isfile(motifs_precalculated_dict_pickle_path):
        print(f'No precalculated motifs distributions found, re-calculating')
        motifs_precalculated_dict_pickle_path = None
    else:
        print(f'using precalculated motifs distributions')
        
    find_motifs_no_redundant_edges(g=subgraph_gt, motif_len=motifs_len, name_to_save_by=subgraph_name, dir_to_save_path=path_to_save_plots_dir, motifs_precalculated_dict_pickle_path=motifs_precalculated_dict_pickle_path)

# %% [markdown]
# ## Random subgraph rewiring and motifs distributions surprise factor analysis

# %%
def rewire_subgraph_and_compare_motifs(subgraph, motifs_len_to_compare, n_shuffles_to_create=1000, **kwargs):
    subgraph_shuffeled = subgraph.copy()
    shuffling_dif_factors = {}
    org_motif_dist = calc_motifs_no_redundant_edges(subgraph, motifs_len_to_compare)
#     print(f"org motifs num: {len(org_motif_dist)}")
    for shuffle_iter in range(n_shuffles_to_create):
        
        random_rewire(subgraph_shuffeled, model=kwargs.get('shuffle_model', 'configuration'),
                                n_iter=kwargs.get('shuffle_iters', 1),
                                edge_sweep=kwargs.get('shuffle_edge_sweep', True),
                                parallel_edges=kwargs.get('shuffle_parallel_edges', False))
        shuffled_motif_dist = calc_motifs_no_redundant_edges(subgraph_shuffeled, motifs_len_to_compare)
#         print(f"shuf motifs num: {len(shuffled_motif_dist)}")
        sub_graphs_not_found_in_org = []
        for shuf_motif in shuffled_motif_dist.keys():
            for org_motif in org_motif_dist.keys():
                if isomorphism(org_motif, shuf_motif):
                    org_motif_cnt = org_motif_dist[org_motif]['motif_count']
                    shuffled_motif_cnt = shuffled_motif_dist[shuf_motif]['motif_count']
                    shuffled_diff_factor = org_motif_cnt/shuffled_motif_cnt
                    shuffling_dif_factors[org_motif] = shuffling_dif_factors.get(org_motif, []) + [shuffled_diff_factor] 
                    break

    
    subgraph_motifs_dif_factors = {}
    for motif, motif_dif_factors in shuffling_dif_factors.items():
        motif_dif_factors_avg = np.mean(motif_dif_factors)
        subgraph_motifs_dif_factors[motif] = motif_dif_factors_avg
    
    if kwargs.get('save_to_pickle_path', None) is not None:
        _path = kwargs.get('save_to_pickle_path')
        with open(_path , 'wb') as f:
            pickle.dump(subgraph_motifs_dif_factors, f)
    
    return subgraph_motifs_dif_factors, sub_graphs_not_found_in_org

# %%
def get_flag(motif_type):
    graph_draw(motif_type, output='tmp/t.png', output_size=(15, 15))
    path = "tmp/t.png"
    im = plt.imread(path)
    return im

def offset_image(coord, motif_type, ax):
    img = get_flag(motif_type)
    im = OffsetImage(img, zoom=1)
    im.image.axes = ax

    ab = AnnotationBbox(im, (coord, 0),  xybox=(0., -16.), frameon=False,
                        xycoords='data',  boxcoords="offset points", pad=0)

    ax.add_artist(ab)
    
def plot_non_randomality_factor_per_subgraph(subgraph_motifs_dif_factors, subgraph_name, path_to_save_plot_dir = None, motifs_len: int =4):
    """
    plots with motifs ilustration (graph_draw) as axis labels
    """
    motifs_types = list(subgraph_motifs_dif_factors.keys())
    valuesA = list(subgraph_motifs_dif_factors.values())
    if len(valuesA) > 10:
        path_to_save_plot_dir = os.path.join(path_to_save_plot_dir, f'{subgraph_name}_non_randomality_score')
        if not os.path.isdir(path_to_save_plot_dir):
            os.makedirs(path_to_save_plot_dir, exist_ok=True)
            
        index = 0
        for i1, i2 in zip(range(0, len(valuesA), 10), range(10, len(valuesA)+9, 10)):
            motif_types_tmp, valuesA_tmp = motifs_types[i1: i2], valuesA[i1: i2]
            fig, ax = plt.subplots()

            ax.bar(range(len(motif_types_tmp)), valuesA_tmp, width=0.5, align="center")
            ax.set_xticks(range(len(motif_types_tmp)))
            ax.set_xticklabels([])
            ax.tick_params(axis='x', which='major', pad=26)

            for bars in ax.containers:
                ax.bar_label(bars)   

            ax.set_title(f"{subgraph_name} motifs non-randomality factor")

            for i, motif_type in enumerate(motif_types_tmp):
                offset_image(i, motif_type, ax)
            if path_to_save_plot_dir is None:
                plt.show()
            else:
                path_to_save_plot = os.path.join(path_to_save_plot_dir, f"{subgraph_name}_non_randomality_factor_motifsLen_{motifs_len}_{index}.png")
                plt.savefig(path_to_save_plot, dpi=300)
                index+=1
    else:
        fig, ax = plt.subplots()

        ax.bar(range(len(motifs_types)), valuesA, width=0.5, align="center")
        ax.set_xticks(range(len(motifs_types)))
        ax.set_xticklabels([])
        ax.tick_params(axis='x', which='major', pad=26)

        for bars in ax.containers:
            ax.bar_label(bars)   

        ax.set_title(f"{subgraph_name} motifs non-randomality factor")

        for i, motif_type in enumerate(motifs_types):
            offset_image(i, motif_type, ax)
        if path_to_save_plot_dir is None:
            plt.show()
        else:
            path_to_save_plot = os.path.join(path_to_save_plot_dir, f"{subgraph_name}_non_randomality_factor_motifsLen_{motifs_len}.png")
            plt.savefig(path_to_save_plot, dpi=200)

# %%
motifs_len = 4
non_randomality_shuffles_num = 1000

# %%
subgraphs_dir = '/scratch/mice_subgraphs/subgraphsByAnnotationLabels'
path_to_save_dir = f'/scratch/motifsDistributions/NonRandomalityFactor/shufflesNum_{n_shuffles_to_create}/motifSize_{motifs_len}'

if not os.path.isdir(path_to_save_dir):
    os.makedirs(path_to_save_dir, exist_ok=True)

subgraphs_names = os.listdir(subgraphs_dir)

sorted_subgraph_names = list(sorted(subgraphs_names))
for subgraph_name in sorted_subgraph_names[:]:
    print(subgraph_name)    
    subgraph_path = os.path.join(subgraphs_dir, subgraph_name)
    subgraph_gt = load_graph(subgraph_path)
    if subgraph_gt.num_vertices() > 10**4:
        continue

    os.makedirs(path_to_save_dir, exist_ok=True)
    path_to_save_info = os.path.join(path_to_save_dir, 
                                     f'{subgraph_name}_motifsLen_{motifs_len}_non_randomality_factor_pickle')
    res = rewire_subgraph_and_compare_motifs(subgraph_gt, motifs_len,
                                             n_shuffles_to_create=n_shuffles_to_create,
                                             save_to_pickle_path=path_to_save_info)
# Out:
# subgraph_area_Ansiform lobule.gt
# subgraph_area_Anterior tegmental nucleus.gt
# subgraph_area_Basic cell groups and regions.gt
# subgraph_area_Basomedial amygdalar nucleus.gt
# subgraph_area_Central lobule.gt
# subgraph_area_Claustrum.gt
# subgraph_area_Copula pyramidis.gt
# subgraph_area_Cortical subplate.gt
# subgraph_area_Culmen.gt
# subgraph_area_Cuneiform nucleus.gt
# subgraph_area_Declive (VI).gt
# subgraph_area_Dentate nucleus.gt
# subgraph_area_Edinger-Westphal nucleus.gt
# subgraph_area_Fastigial nucleus.gt
# subgraph_area_Flocculus.gt
# subgraph_area_Folium-tuber vermis (VII).gt
# subgraph_area_Hippocampal formation.gt
# subgraph_area_Hypothalamus.gt
# subgraph_area_Inferior colliculus.gt
# subgraph_area_Interposed nucleus.gt
# subgraph_area_Isocortex.gt
# subgraph_area_Lateral amygdalar nucleus.gt
# subgraph_area_Lateral terminal nucleus of the accessory optic tract.gt
# subgraph_area_Lingula (I).gt
# subgraph_area_Medulla.gt
# subgraph_area_Midbrain reticular nucleus, retrorubral area.gt
# subgraph_area_Midbrain reticular nucleus.gt
# subgraph_area_Midbrain trigeminal nucleus.gt
# subgraph_area_Midbrain.gt
# subgraph_area_Nodulus (X).gt
# subgraph_area_Nucleus of the brachium of the inferior colliculus.gt
# subgraph_area_Nucleus sagulum.gt
# subgraph_area_Oculomotor nucleus.gt
# subgraph_area_Olfactory areas.gt
# subgraph_area_Pallidum.gt
# subgraph_area_Parabigeminal nucleus.gt
# subgraph_area_Paraflocculus.gt
# subgraph_area_Paramedian lobule.gt
# subgraph_area_Pedunculopontine nucleus.gt
# subgraph_area_Periaqueductal gray.gt
# subgraph_area_Pons.gt
# subgraph_area_Posterior amygdalar nucleus.gt
# subgraph_area_Pyramus (VIII).gt
# subgraph_area_Red nucleus.gt
# subgraph_area_Simple lobule.gt
# subgraph_area_Striatum-like amygdalar nuclei.gt
# subgraph_area_Striatum.gt
# subgraph_area_Substantia nigra, compact part.gt
# subgraph_area_Substantia nigra, reticular part.gt
# subgraph_area_Thalamus.gt
# subgraph_area_Trochlear nucleus.gt
# subgraph_area_Uvula (IX).gt
# subgraph_area_Ventral tegmental area.gt
# subgraph_area_Ventral tegmental nucleus.gt
# subgraph_area_alveus.gt
# subgraph_area_amygdalar capsule.gt
# subgraph_area_anterior commissure, olfactory limb.gt
# subgraph_area_anterior commissure, temporal limb.gt
# subgraph_area_arbor vitae.gt
# subgraph_area_brachium of the inferior colliculus.gt
# subgraph_area_brain.gt
# subgraph_area_cerebal peduncle.gt
# subgraph_area_cerebral aqueduct.gt
# subgraph_area_cingulum bundle.gt
# subgraph_area_corpus callosum.gt
# subgraph_area_corticospinal tract.gt
# subgraph_area_doral tegmental decussation.gt
# subgraph_area_dorsal fornix.gt
# subgraph_area_external medullary lamina of the thalamus.gt
# subgraph_area_facial nerve.gt
# subgraph_area_fasciculus retroflexus.gt
# subgraph_area_fiber tracts.gt
# subgraph_area_fimbria.gt
# subgraph_area_fourth ventricle.gt
# subgraph_area_habenular commissure.gt
# subgraph_area_inferior cerebellar peduncle.gt
# subgraph_area_inferior colliculus commissure.gt
# subgraph_area_internal capsule.gt
# subgraph_area_internal medullary lamina of the thalamus.gt
# subgraph_area_lateral lemniscus.gt
# subgraph_area_lateral olfactory tract, body.gt
# subgraph_area_lateral recess.gt
# subgraph_area_lateral ventricle.gt
# subgraph_area_mammillary peduncle.gt
# subgraph_area_mammillotegmental tract.gt
# subgraph_area_mammillothalamic tract.gt
# subgraph_area_medial lemniscus.gt
# subgraph_area_medial longitudinal fascicle.gt
# subgraph_area_midbrain tract of the trigeminal nerve.gt
# subgraph_area_middle cerebellar peduncle.gt
# subgraph_area_motor root of the trigeminal nerve.gt
# subgraph_area_olfactory nerve layer of main olfactory bulb.gt
# subgraph_area_optic chiasm.gt
# subgraph_area_optic tract.gt
# subgraph_area_posterior commissure.gt
# subgraph_area_principal mammillary tract.gt
# subgraph_area_pyramid.gt
# subgraph_area_rubrospinal tract.gt
# subgraph_area_solitary tract.gt
# subgraph_area_spinal tract of the trigeminal nerve.gt
# subgraph_area_stria medullaris.gt
# subgraph_area_stria terminalis.gt
# subgraph_area_superior cerebelar peduncles.gt
# subgraph_area_supramammillary decussation.gt
# subgraph_area_tectospinal pathway.gt
# subgraph_area_third ventricle.gt
# subgraph_area_trapezoid body.gt
# subgraph_area_trochlear nerve.gt
# subgraph_area_universe.gt
# subgraph_area_ventral tegmental decussation.gt
# subgraph_area_ventricular systems.gt
# subgraph_area_vestibular nerve.gt

# %%
subgraphs_dir = '/scratch/mice_subgraphs/subgraphsByAnnotationLabels'

subgraphs_names = os.listdir(subgraphs_dir)

path_to_save_plots_dir = f'/home/yishaiaz/SubgraphsMotifsResults/MiceSubgraphsResults/MotifsNonRandomalityFactorsByAnnotation/shufflesNum_{non_randomality_shuffles_num}/MotifSize_{motifs_len}'

os.makedirs(path_to_save_plots_dir, exist_ok=True)
sorted_subgraph_names = list(sorted(subgraphs_names))

for subgraph_name in sorted_subgraph_names[:]:
    print(subgraph_name)    

    path_to_non_randomallity_info_dir = f'/scratch/motifsDistributions/NonRandomalityFactor/shufflesNum_{non_randomality_shuffles_num}/motifSize_{motifs_len}'
    path_to_motif_non_randomallity_info = os.path.join(path_to_non_randomallity_info_dir,
                                                       f'{subgraph_name}_motifsLen_{motifs_len}_non_randomality_factor_pickle')
    if not os.path.isfile(path_to_motif_non_randomallity_info):
        continue
        
    with open(path_to_motif_non_randomallity_info, 'rb') as f:
        motif_non_randomallity_info = pickle.load(f)
        print(len(motif_non_randomallity_info))
        plot_non_randomality_factor_per_subgraph(motif_non_randomallity_info,
                                                 subgraph_name, motifs_len=motifs_len, 
                                                 path_to_save_plot_dir=path_to_save_plots_dir)
# Out:
# subgraph_area_Ansiform lobule.gt
# subgraph_area_Anterior tegmental nucleus.gt
# 4
# subgraph_area_Basic cell groups and regions.gt
# 2
# subgraph_area_Basomedial amygdalar nucleus.gt
# 5
# subgraph_area_Central lobule.gt
# subgraph_area_Claustrum.gt
# 4
# subgraph_area_Copula pyramidis.gt
# subgraph_area_Cortical subplate.gt
# 4
# subgraph_area_Culmen.gt
# subgraph_area_Cuneiform nucleus.gt
# 4
# subgraph_area_Declive (VI).gt
# subgraph_area_Dentate nucleus.gt
# 5
# subgraph_area_Edinger-Westphal nucleus.gt
# 5
# subgraph_area_Fastigial nucleus.gt
# 4
# subgraph_area_Flocculus.gt
# subgraph_area_Folium-tuber vermis (VII).gt
# 4
# subgraph_area_Hippocampal formation.gt
# subgraph_area_Hypothalamus.gt
# subgraph_area_Inferior colliculus.gt
# subgraph_area_Interposed nucleus.gt
# subgraph_area_Isocortex.gt
# subgraph_area_Lateral amygdalar nucleus.gt
# 5
# subgraph_area_Lateral terminal nucleus of the accessory optic tract.gt
# 2
# subgraph_area_Lingula (I).gt
# 5
# subgraph_area_Medulla.gt
# subgraph_area_Midbrain reticular nucleus, retrorubral area.gt
# 4
# subgraph_area_Midbrain reticular nucleus.gt
# subgraph_area_Midbrain trigeminal nucleus.gt
# 4
# subgraph_area_Midbrain.gt
# subgraph_area_Nodulus (X).gt
# subgraph_area_Nucleus of the brachium of the inferior colliculus.gt
# 5
# subgraph_area_Nucleus sagulum.gt
# 4
# subgraph_area_Oculomotor nucleus.gt
# 5
# subgraph_area_Olfactory areas.gt
# subgraph_area_Pallidum.gt
# 4
# subgraph_area_Parabigeminal nucleus.gt
# 5
# subgraph_area_Paraflocculus.gt
# subgraph_area_Paramedian lobule.gt
# subgraph_area_Pedunculopontine nucleus.gt
# 4
# subgraph_area_Periaqueductal gray.gt
# subgraph_area_Pons.gt
# subgraph_area_Posterior amygdalar nucleus.gt
# 4
# subgraph_area_Pyramus (VIII).gt
# subgraph_area_Red nucleus.gt
# 4
# /tmp/ipykernel_421503/2199489974.py:52: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# subgraph_area_Simple lobule.gt
# subgraph_area_Striatum-like amygdalar nuclei.gt
# subgraph_area_Striatum.gt
# subgraph_area_Substantia nigra, compact part.gt
# 4
# subgraph_area_Substantia nigra, reticular part.gt
# 4
# subgraph_area_Thalamus.gt
# subgraph_area_Trochlear nucleus.gt
# 3
# subgraph_area_Uvula (IX).gt
# subgraph_area_Ventral tegmental area.gt
# 4
# subgraph_area_Ventral tegmental nucleus.gt
# 5
# subgraph_area_alveus.gt
# 5
# subgraph_area_amygdalar capsule.gt
# 4
# subgraph_area_anterior commissure, olfactory limb.gt
# 5
# subgraph_area_anterior commissure, temporal limb.gt
# 5
# subgraph_area_arbor vitae.gt
# subgraph_area_brachium of the inferior colliculus.gt
# 5
# subgraph_area_brain.gt
# 0
# subgraph_area_cerebal peduncle.gt
# 4
# subgraph_area_cerebral aqueduct.gt
# 5
# subgraph_area_cingulum bundle.gt
# 5
# subgraph_area_corpus callosum.gt
# subgraph_area_corticospinal tract.gt
# 5
# subgraph_area_doral tegmental decussation.gt
# 5
# subgraph_area_dorsal fornix.gt
# 5
# subgraph_area_external medullary lamina of the thalamus.gt
# 4
# subgraph_area_facial nerve.gt
# 5
# subgraph_area_fasciculus retroflexus.gt
# 5
# subgraph_area_fiber tracts.gt
# subgraph_area_fimbria.gt
# subgraph_area_fourth ventricle.gt
# subgraph_area_habenular commissure.gt
# 5
# subgraph_area_inferior cerebellar peduncle.gt
# 4
# subgraph_area_inferior colliculus commissure.gt
# 5
# subgraph_area_internal capsule.gt
# 4
# subgraph_area_internal medullary lamina of the thalamus.gt
# 0
# subgraph_area_lateral lemniscus.gt
# 4
# subgraph_area_lateral olfactory tract, body.gt
# 4
# subgraph_area_lateral recess.gt
# 4
# subgraph_area_lateral ventricle.gt
# subgraph_area_mammillary peduncle.gt
# 2
# subgraph_area_mammillotegmental tract.gt
# 4
# subgraph_area_mammillothalamic tract.gt
# 4
# subgraph_area_medial lemniscus.gt
# 4
# subgraph_area_medial longitudinal fascicle.gt
# subgraph_area_midbrain tract of the trigeminal nerve.gt
# 3
# subgraph_area_middle cerebellar peduncle.gt
# 4
# subgraph_area_motor root of the trigeminal nerve.gt
# 4
# subgraph_area_olfactory nerve layer of main olfactory bulb.gt
# 4
# subgraph_area_optic chiasm.gt
# 5
# subgraph_area_optic tract.gt
# 5
# subgraph_area_posterior commissure.gt
# 4
# subgraph_area_principal mammillary tract.gt
# 0
# subgraph_area_pyramid.gt
# 4
# subgraph_area_rubrospinal tract.gt
# 5
# subgraph_area_solitary tract.gt
# 3
# subgraph_area_spinal tract of the trigeminal nerve.gt
# 4
# subgraph_area_stria medullaris.gt
# 5
# subgraph_area_stria terminalis.gt
# 5
# subgraph_area_superior cerebelar peduncles.gt
# 5
# subgraph_area_supramammillary decussation.gt
# 4
# subgraph_area_tectospinal pathway.gt
# 5
# subgraph_area_third ventricle.gt
# subgraph_area_trapezoid body.gt
# 4
# subgraph_area_trochlear nerve.gt
# 4
# subgraph_area_universe.gt
# subgraph_area_ventral tegmental decussation.gt
# 5
# subgraph_area_ventricular systems.gt
# 5
# subgraph_area_vestibular nerve.gt
# 5

# %% [markdown]
# ## Motifs with structural elements

# %%
from itertools import chain, combinations

motifs_len = 4
subgraphs_dir = '/scratch/mice_subgraphs/subgraphsByAnnotationLabels'
subgraphs_names = os.listdir(subgraphs_dir)
subgraph_name = subgraphs_names[0]
g = load_graph(subgraph_path)
remove_parallel_edges(g)
motifs, motifs_cnts, motifs_vertex_properties = clst.motifs(g, k=motifs_len, p=1.0, return_maps=True)
[v for v in motifs_vertex_properties[0][1]], list(combinations([v for v in motifs_vertex_properties[0][1]], 2))

# %%
from itertools import combinations
from warnings import warn




def get_all_edges_from_vertices_ids(g, motifs_v_ids, collect_properties: Union[None, Dict[str, List[str]]]):
    def collect_properties_helper_func(_g, props_to_collect, ids_to_collect_by, graph_component: str):
        if graph_component != 'v' and graph_component != 'e':
            raise KeyError(f"Supports graph_component value 'v' or 'e' only! got {graph_component}")
        for prop in props_to_collect:
            try:
                prop_map = _g.vp[prop] if graph_component=='v' else _g.ep[prop]
            except KeyError as e:
                warn(f"could not find {'vertex' if graph_component=='v' else 'edge'} property map '{prop}', skipping")
            else:
                motif_prop_values = np.array([prop_map[_id] for _id in ids_to_collect_by])
                if prop_map.value_type() == 'bool':
                    # collect all properties and choose by majority
                    unique, counts = np.unique(motif_prop_values, return_counts=True)
                    motif_prop_rep_val = bool(unique[counts.argmax()])
                elif prop_map.value_type() == 'double':
                    # collect all properties and calc mean
                    motif_prop_rep_val = np.mean(motif_prop_values)
                elif prop_map.value_type().startswith('vector<'):
                    warn(f"Vector properties are not supported yet! recieved {'vertex' if graph_component=='v' else 'edge'} property {prop}")
                motif_properties[f"{graph_component}_{prop}"] = motif_prop_rep_val
                
        return motif_properties
    
    all_possible_edges = list(combinations([v for v in motifs_v_ids], 2))
    all_real_edges = []
    for possible_e in all_possible_edges:
        edge = g.edge(possible_e[0], possible_e[1], all_edges=False, add_missing=False)
        if edge is not None:
            all_real_edges.append(edge)
    # collecting properties if names were provided
    if collect_properties is not None:
        e_props_to_collect, v_props_to_collect = collect_properties['e_props'], collect_properties['v_props']

        motif_properties = {}
        motif_properties.update(collect_properties_helper_func(g, props_to_collect=v_props_to_collect, 
                                                  ids_to_collect_by=motifs_v_ids, graph_component='v'))
        motif_properties.update(collect_properties_helper_func(g, props_to_collect=e_props_to_collect, 
                                                  ids_to_collect_by=all_real_edges, graph_component='e'))

        return all_real_edges, motif_properties
        
    return all_real_edges

    
def find_motif_structural_properties(motif, motif_v_props):
    pass

# %%
motifs_props_to_collect = {
    'v_props' : ['radii', 'artery_binary', 'distance_to_surface', 'coordinates'],
    'e_props' : ['radii', 'artery_binary', 'distance_to_surface', 'coordinates']
}
get_all_edges_from_vertices_ids(g, motifs_vertex_properties[0][1], motifs_props_to_collect)

# %%
prop_map = g.vp['coordinates']
prop_map.value_type()

# %% [markdown]
# # Motifs Exploration

# %%
# GRAPH_SSD_PATH = '/scratch/data_graph.gt'
GRAPH_SSD_PATH = '/scratch/yishaiaz@auth.ad.bgu.ac.il/3735255/data_graph.gt'
entire_graph = load_graph(GRAPH_SSD_PATH)

# %%
os.listdir('/scratch/yishaiaz@auth.ad.bgu.ac.il/3735255/data_graph.gt')

# %%
# get a subgraph of specific areas, i.e. filter graph by specific annotation
np.unique(entire_graph.vp['annotation'].a)

# %%
motif_len = 4
motifs, motifs_cnts, motifs_vertex_properties = clst.motifs(entire_graph, k=motif_len, p=1.0, return_maps=True)

# %%
(motifs_vertex_properties[0])

# %%
PREV_RESULTS_DIR = 'GBVasculatureGraphsAnalysis/~/MOTIF_DISTRIBUTIONS_RESULTS'
os.listdir(PREV_RESULTS_DIR)

# %%
with open(os.path.join(PREV_RESULTS_DIR, 'motifs_undirected.pckl'), 'rb') as f:
    motifs = pickle.load(f)
with open(os.path.join(PREV_RESULTS_DIR, 'motifs_cnts_undirected.pckl'), 'rb') as f:
    motifs_cnt = pickle.load(f)
motifs_cnt

# %%
with open(os.path.join(PREV_RESULTS_DIR, 'motifs_vertex_props.pckl'), 'rb') as f:
    motifs_vertex_props = pickle.load(f)
motifs_vertex_props

# %%
from copy import copy, deepcopy

motifs_with_no_redundant_edges = []
motifs_with_no_redundant_edges_cnts = []
motifs_with_no_redundant_edges_properties = []
print('copying motifs and counts')
motifs_cpy = deepcopy(motifs)
motifs_cnt_cpy = deepcopy(motifs_cnt)
motifs_vertex_props_cpy = deepcopy(motifs_vertex_properties)

print('started gathering motifs from copy')
while len(motifs_cpy)>0:
    print(len(motifs_cpy))
    motif1, motif1_cnt, motifs1_props = motifs_cpy[0], motifs_cnt_cpy[0], motifs_vertex_props_cpy[0]
    motif_new_count = motif1_cnt
    combined_motif1_properties = list(motifs1_props)
    for _motif2_idx, _motif2 in enumerate(motifs_cpy[1:]):
        if isomorphism(motif1, _motif2) and motif1 is not _motif2:
            motif_new_count += motifs_cnt_cpy[_motif2_idx]
            combined_motif1_properties += list(motifs_vertex_props_cpy[_motif2_idx])
            del motifs_cpy[_motif2_idx], motifs_cnt_cpy[_motif2_idx], motifs_vertex_props_cpy[_motif2_idx]
    
    motifs_with_no_redundant_edges.append(motif1) 
    motifs_with_no_redundant_edges_cnts.append(motif_new_count)
    motifs_with_no_redundant_edges_properties.append(combined_motif1_properties)
    
    del motifs_cpy[0]
#     _motif1_idx+=1
    
# for motif1, motif1_cnt, motifs1_props in zip(motifs_cpy, motifs_cnt_cpy, motifs_vertex_props_cpy):
#     motif_new_count = motif1_cnt
#     combined_motif1_properties = list(motifs1_props)
#     _motif1_idx += 1
#     for _motif2_idx, _motif2 in enumerate(motifs_cpy):
#         if isomorphism(motif1, _motif2) and motif1 is not _motif2:
#             motif_new_count += motifs_cnt_cpy[_motif2_idx]
#             combined_motif1_properties += list(motifs_vertex_props_cpy[_motif2_idx])
#             del motifs_cpy[_motif2_idx], motifs_cnt_cpy[_motif2_idx], motifs_vertex_props_cpy[_motif2_idx]
            
#     motifs_with_no_redundant_edges.append(motif1) 
#     motifs_with_no_redundant_edges_cnts.append(motif_new_count)
#     motifs_with_no_redundant_edges_properties.append(combined_motif1_properties)
#     motif_no_duplicates = remove_parallel_edges(motif)
#     motifs_with_no_redundant_edges.append(motif_no_duplicates)

# %%
entire_graph.num_vertices(), len(motifs_with_no_redundant_edges_properties)#, motifs_with_no_redundant_edges_cnts, motifs_with_no_redundant_edges_properties[0]

# %%
motifs_with_no_redundant_edges_properties

# %%
motifs_knowledge_dictionary = {
    'motifs_graphs': motifs_with_no_redundant_edges,
    'motifs_counts': motifs_with_no_redundant_edges_cnts, 
    'motifs_properties_maps': motifs_with_no_redundant_edges_properties
}
file_path = os.path.join(PREV_RESULTS_DIR, 'motifs_knowledge_dictionary.pckl')
with open(file_path, 'wb') as file:
    pickle.dump(motifs_knowledge_dictionary, file)

# %%
# [(key, len(item)) for key, item in motifs_knowledge_dictionary.items()]
_v_id = list(motifs_with_no_redundant_edges_properties[0][0])[0]
# entire_graph.vp['annotation'][_v_id]
# entire_graph.vertex(v_id).properties
len(motifs_knowledge_dictionary["motifs_properties_maps"][1])

# %%
c

# %%
file_path = os.path.join(PREV_RESULTS_DIR, 'motifs_cnt_per_annotation_label.pckl')
with open(file_path, 'wb') as file:
    pickle.dump(motifs_cnt_per_annotation_label, file)

# %%
entire_graph.num_vertices()

# %%
motifs_with_no_redundant_edges
motifs_with_no_redundant_edges_cnts

sum_of_all_motifs_counts = sum(motifs_with_no_redundant_edges_cnts)
for motif, motif_cnt in zip(motifs_with_no_redundant_edges, motifs_with_no_redundant_edges_cnts):
    print(f"motif count: {motif_cnt}, fraction of all motifs: {motif_cnt/sum_of_all_motifs_counts}")
    pos = sfdp_layout(motif)
    graph_draw(motif, pos=pos)#, output="graph-draw-sfdp.pdf")
